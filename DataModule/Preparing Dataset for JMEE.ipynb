# %%
import glob
import xml.etree.ElementTree as ET
import re

# %%
class Argument(object):
    def __init__(self, id_, start, end, role, text):
        self.id_ = id_
        self.start = start
        self.end = end
        self.role = role
        self.text = text

    def to_string(self):
        return "Argument: {id_ = " + self.id_ + ", role = " + self.role + ", text = " + self.text + "}"
    
class Entity(object):
    def __init__(self, phrase_type, end, text, entity_type, start, id_):
        self.phrase_type = phrase_type
        self.end = end
        self.text = text
        self.entity_type = entity_type
        self.start = start
        self.id_ = id_

    def to_string(self):
        return "Entity: {id_ = " + self.id_ + ", entity_type = " + self.entity_type + ", text = " + self.text + ", phrase_type=" + self.phrase_type +"}"

class Sentence(object):
    def __init__(self, text, start, end):
        self.text = text
        self.start = start
        self.end = end

    def to_string(self):
        return "Sentence: {text = " + self.text + ", start = " + self.start + ", end = " + self.end + "}"
    
    def __str__(self):
        return str(self.__dict__)

    def __eq__(self, other): 
        return self.__dict__ == other.__dict__
    
    def __hash__(self):
        return hash(self)

class Event(object):
    def __init__(self, event_id, mention_id, type_, subtype, modality, polarity, genericity, tense, extent, extent_start, extent_end, scope, trig_text, trig_start, trig_end, arguments, entities):
        self.event_id = event_id
        self.mention_id = mention_id
        self.type_ = type_
        self.subtype = subtype
        self.modality = modality
        self.polarity = polarity
        self.genericity = genericity
        self.tense = tense
        self.extent = extent
        self.extent_start = extent_start
        self.extent_end = extent_end
        self.scope = scope
        self.trig_text = trig_text
        self.trig_start = trig_start
        self.trig_end = trig_end
        self.arguments = arguments
        self.entities = entities


    def to_string(self):
        return "Event: { event_id = " + self.event_id + "mention_id = " + self.mention_id + ", type = " + self.type_ + ", subtype = " +self.subtype + ", modality = " \
               + self.modality + ", polarity = " + self.polarity + ", genericity= " + self.genericity + ", tense = " +\
               self.tense + ", extent = " +self.extent + ", scope = " + self.scope  + ", trigger = " + self.trigger

# %%
def extract_entity_info(entity, scope_start, scope_end, extent, words_start, words_end, extent_start):
    entity_id = entity.attrib["ID"]
    phrase_type = entity.attrib["TYPE"] + ":" + entity.attrib["SUBTYPE"]
    entity_class = entity.attrib["CLASS"]

    entities = []
    for mention in entity.iter('entity_mention'):
        entity_type = mention.attrib["LDCTYPE"]
        for child in mention:
            if child.tag == "extent":
                for chil2 in child:
                    text = chil2.text
                    start = int(chil2.attrib["START"])
                    end = int(chil2.attrib["END"])
                    
                    list_end = list(words_end.keys())
                    list_start = list(words_start.keys())
            
                    a_end = words_end[findClosest(list_end, len(list_end), end)]
                    a_start = words_start[findClosest(list_start, len(list_start), start)]
                    
        if scope_start <= start and  scope_end >= end:              
            ent = Entity(phrase_type, a_end, text, entity_type, a_start, entity_id)
            entities.append(ent)
        
    return entities

# %%
class Word(object):
    def __init__(self, start, end):
        #self.str_ = str_
        self.start = start
        self.end = end

# %%
def find_positions(sent):
    parse, = dep_parser.raw_parse(sent)
    i = 0
    words_start = {}
    words_end = {}
    accu_sum = 0
    i = 1
    for part in parse.to_conll(4).split("\n"):
        if part != "":
            parts = part.split("\t")
            word = parts[0]
            word_start = accu_sum
            word_end = accu_sum + len(word)
            accu_sum += len(word) + 1
            words_start.update({word_start: i})
            words_end.update({word_end: i})
            i+=1
    return words_start, words_end

# %%
def extract_from_xml(root_path, language, domain):
    events = {}
    #print(root_path + language + "/" + domain + "/adj/*.apf.xml")
    files_processed = 0
    for file_name in sorted(glob.glob(root_path + language + "/" + domain + "/adj/*.apf.xml")):        
        # Get the event + argument annotation
        print("file_name=", file_name)
        files_processed += 1
        tree = ET.parse(file_name, ET.XMLParser(encoding='utf-8'))
        root = tree.getroot()
        
        for event in root.iter('event'):
            sent, ev = extract_event_info(root, event)
            if sent.text not in events:
                events.update({sent.text: [ev]}) 
            else:
                ev_list = events[sent.text]
                ev_list.append(ev)
                events.update({sent.text: ev_list})
                
        
    return events, files_processed

# %%
import math
def findClosest(arr, n, target): 
  
    # Corner cases 
    if (target <= arr[0]): 
        return arr[0] 
    if (target >= arr[n - 1]): 
        return arr[n - 1] 
  
    # Doing binary search 
    i = 0; j = n; mid = 0
    while (i < j):  
        mid = math.floor((i + j) / 2)
  
        if (arr[mid] == target): 
            return arr[mid] 
  
        # If target is less than array  
        # element, then search in left 
        if (target < arr[mid]) : 
  
            # If target is greater than previous 
            # to mid, return closest of two 
            if (mid > 0 and target > arr[mid - 1]): 
                return getClosest(arr[mid - 1], arr[mid], target) 
  
            # Repeat for left half  
            j = mid 
          
        # If target is greater than mid 
        else : 
            if (mid < n - 1 and target < arr[mid + 1]): 
                return getClosest(arr[mid], arr[mid + 1], target) 
                  
            # update i 
            i = mid + 1
          
    # Only single element left after search 
    return arr[mid]

# %%
def getClosest(val1, val2, target): 
  
    if (target - val1 >= val2 - target): 
        return val2 
    else: 
        return val1

# %%
def extract_event_info(root, event):
    event_id = event.attrib["ID"]
    event_type = event.attrib["TYPE"]
    subtype = event.attrib["SUBTYPE"]
    modality = event.attrib["MODALITY"]
    polarity = event.attrib["POLARITY"]
    genericity = event.attrib["GENERICITY"]
    tense = event.attrib["TENSE"]

    ## Looking at event mentions
    for mention in event.iter('event_mention'):
        mention_id = mention.attrib["ID"]
        for child in mention:
            if child.tag == "extent":
                for chil2 in child:
                    extent = chil2.text
                    extent_start = int(chil2.attrib["START"])
                    extent_end = int(chil2.attrib["END"]) 
                    words_start, words_end = find_positions(extent)
                
            elif child.tag == "ldc_scope":
                for chil2 in child:
                    scope = chil2.text
                    scope_start = int(chil2.attrib["START"])
                    scope_end = int(chil2.attrib["END"])
                sent = Sentence(scope, scope_start, scope_end)
                
            elif child.tag == "anchor":
                for chil2 in child:
                    trig_text = chil2.text
                    trig_start = int(chil2.attrib["START"]) - extent_start
                    trig_end = int(chil2.attrib["END"]) - extent_start
                    
                    list_end = list(words_end.keys())
                    list_start = list(words_start.keys())
                    
                    t_end = words_end[findClosest(list_end, len(list_end), trig_end)]
                    t_start = words_start[findClosest(list_start, len(list_start), trig_start)]
        

        arguments = []           
        for argument in mention.iter('event_mention_argument'):
            arg_id = argument.attrib["REFID"]
            role = argument.attrib["ROLE"]
            for child in argument:
                for chil2 in child:
                    arg_text = chil2.text
                    arg_start = int(chil2.attrib["START"]) - extent_start
                    arg_end = int(chil2.attrib["END"]) - extent_start
                    
                    list_end = list(words_end.keys())
                    list_start = list(words_start.keys())
            
                    a_end = words_end[findClosest(list_end, len(list_end), arg_end)]
                    a_start = words_start[findClosest(list_start, len(list_start), arg_start)]
                        
            arg = Argument(arg_id, a_start, a_end, role, arg_text)

            arguments.append(arg)
       
        ## Looking at entity mentions with that same event
        entities = []
        for entity in root.iter('entity'):
            entities.extend(extract_entity_info(entity, scope_start, scope_end, extent, words_start, words_end, extent_start))

    ev = Event(event_id, mention_id, event_type, subtype, modality, polarity, genericity, tense, extent, extent_start, extent_end, scope, trig_text, t_start, t_end, arguments, entities)

    return sent, ev

# %%
#data_path = "/Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/ACE/Raw/LDC2006T06/data/English/bc/adj/"
root_path = "/Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/"

# %%
languages = [file_.split("/")[-1] for file_ in glob.glob(root_path + "*") if "Icon\r" not in file_]

# %%
events_list_lang = {}

def merge_two_dicts(x, y):
    z = x.copy()   # start with x's keys and values
    z.update(y)    # modifies z with y's keys and values & returns None
    return z

for language in languages:
    files_num = 0
    domains = [file_.split("/")[-1] for file_ in glob.glob(root_path + language + "/*" ) if "Icon\r" not in file_]
    events_lang = {}
    for domain in domains:
        events, files_processed = extract_from_xml(root_path, language, domain)
        files_num += files_processed
        
        events_lang = merge_two_dicts(events_lang, events)
    
    print("Number of files processed for language= ", language, " is= ", files_num)
    
    events_list_lang.update({language: events_lang})
# Out:
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/English/un/adj/Austin-Grad-Community_20050212.2454.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/English/un/adj/Integritas-Group-Community-Forum_20050110.0557.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/English/un/adj/alt.atheism_20041104.2428.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/English/un/adj/alt.collecting.autographs_20050224.2438.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/English/un/adj/alt.corel_20041228.0503.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/English/un/adj/alt.gossip.celebrities_20041118.2331.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/English/un/adj/alt.politics.economics_20041206.1835.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/English/un/adj/alt.politics_20050124.0640.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/English/un/adj/alt.religion.mormon_20050103.0854.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/English/un/adj/alt.support.divorce_20050113.2451.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/English/un/adj/alt.sys.pc-clone.dell_20050226.2350.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/English/un/adj/alt.vacation.las-vegas_20050109.0133.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/English/un/adj/aus.cars_20041206.0903.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/English/un/adj/marcellapr_20050211.2013.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/English/un/adj/marcellapr_20050228.2219.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/English/un/adj/misc.invest.marketplace_20050208.2406.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/English/un/adj/misc.kids.pregnancy_20050120.0404.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/English/un/adj/misc.legal.moderated_20041202.1648.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/English/un/adj/misc.legal.moderated_20050129.2225.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/English/un/adj/misc.taxes_20050218.1250.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/English/un/adj/rec.arts.mystery_20050219.1126.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/English/un/adj/rec.arts.sf.written.robert-jordan_20050208.1350.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/English/un/adj/rec.boats_20050130.1006.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/English/un/adj/rec.games.chess.politics_20041216.1047.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/English/un/adj/rec.music.phish_20041215.1554.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/English/un/adj/rec.music.phish_20050217.1804.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/English/un/adj/rec.parks.theme_20050217.2019.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/English/un/adj/rec.travel.cruises_20050222.0313.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/English/un/adj/rec.travel.usa-canada_20050128.0121.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/English/un/adj/seattle.politics_20050122.2412.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/English/un/adj/soc.culture.china_20050203.0639.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/English/un/adj/soc.culture.hmong_20050210.1130.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/English/un/adj/soc.culture.jewish_20050130.2105.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/English/un/adj/soc.history.war.world-war-ii_20050127.2403.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/English/un/adj/soc.history.what-if_20050129.1404.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/English/un/adj/talk.politics.misc_20050216.1337.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/English/un/adj/uk.gay-lesbian-bi_20050127.0311.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/English/bc/adj/CNN_CF_20030303.1900.00.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/English/bc/adj/CNN_CF_20030303.1900.02.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/English/bc/adj/CNN_CF_20030303.1900.06-1.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/English/bc/adj/CNN_CF_20030303.1900.06-2.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/English/bc/adj/CNN_CF_20030304.1900.01.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/English/bc/adj/CNN_CF_20030304.1900.02.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/English/bc/adj/CNN_CF_20030304.1900.04.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/English/bc/adj/CNN_CF_20030304.1900.06-2.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/English/bc/adj/CNN_CF_20030305.1900.00-1.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/English/bc/adj/CNN_CF_20030305.1900.00-2.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/English/bc/adj/CNN_CF_20030305.1900.00-3.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/English/bc/adj/CNN_CF_20030305.1900.02.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/English/bc/adj/CNN_CF_20030305.1900.06-1.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/English/bc/adj/CNN_CF_20030305.1900.06-2.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/English/bc/adj/CNN_IP_20030328.1600.07.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/English/bc/adj/CNN_IP_20030329.1600.00-2.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/English/bc/adj/CNN_IP_20030329.1600.00-3.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/English/bc/adj/CNN_IP_20030329.1600.00-4.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/English/bc/adj/CNN_IP_20030329.1600.00-5.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/English/bc/adj/CNN_IP_20030329.1600.00-6.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/English/bc/adj/CNN_IP_20030329.1600.01-1.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/English/bc/adj/CNN_IP_20030329.1600.01-3.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/English/bc/adj/CNN_IP_20030330.1600.05-2.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/English/bc/adj/CNN_IP_20030330.1600.06.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/English/bc/adj/CNN_IP_20030402.1600.00-1.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/English/bc/adj/CNN_IP_20030402.1600.00-2.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/English/bc/adj/CNN_IP_20030402.1600.00-4.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/English/bc/adj/CNN_IP_20030402.1600.02-1.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/English/bc/adj/CNN_IP_20030402.1600.02-2.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/English/bc/adj/CNN_IP_20030403.1600.00-1.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/English/bc/adj/CNN_IP_20030403.1600.00-2.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/English/bc/adj/CNN_IP_20030403.1600.00-4.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/English/bc/adj/CNN_IP_20030404.1600.00-1.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/English/bc/adj/CNN_IP_20030404.1600.00-2.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/English/bc/adj/CNN_IP_20030405.1600.00-3.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/English/bc/adj/CNN_IP_20030405.1600.01-1.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/English/bc/adj/CNN_IP_20030405.1600.01-2.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/English/bc/adj/CNN_IP_20030405.1600.01-3.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/English/bc/adj/CNN_IP_20030405.1600.02.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/English/bc/adj/CNN_IP_20030406.1600.03.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/English/bc/adj/CNN_IP_20030408.1600.03.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/English/bc/adj/CNN_IP_20030408.1600.04.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/English/bc/adj/CNN_IP_20030409.1600.04.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/English/bc/adj/CNN_IP_20030410.1600.03-1.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/English/bc/adj/CNN_IP_20030410.1600.03-2.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/English/bc/adj/CNN_IP_20030412.1600.05.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/English/bc/adj/CNN_IP_20030414.1600.04.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/English/bc/adj/CNN_IP_20030417.1600.06.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/English/bc/adj/CNN_IP_20030422.1600.05.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/English/bc/adj/CNN_LE_20030504.1200.01.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/English/bc/adj/CNN_LE_20030504.1200.02-1.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/English/bc/adj/CNN_LE_20030504.1200.02-2.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/English/cts/adj/fsh_29097.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/English/cts/adj/fsh_29105.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/English/cts/adj/fsh_29121.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/English/cts/adj/fsh_29138.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/English/cts/adj/fsh_29139.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/English/cts/adj/fsh_29141.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/English/cts/adj/fsh_29171.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/English/cts/adj/fsh_29187.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/English/cts/adj/fsh_29191.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/English/cts/adj/fsh_29192.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/English/cts/adj/fsh_29195.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/English/cts/adj/fsh_29226.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/English/cts/adj/fsh_29272.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/English/cts/adj/fsh_29302.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/English/cts/adj/fsh_29303.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/English/cts/adj/fsh_29326.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/English/cts/adj/fsh_29336.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/English/cts/adj/fsh_29344.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/English/cts/adj/fsh_29350.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/English/cts/adj/fsh_29361.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/English/cts/adj/fsh_29395.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/English/cts/adj/fsh_29520.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/English/cts/adj/fsh_29521.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/English/cts/adj/fsh_29526.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/English/cts/adj/fsh_29581_1.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/English/cts/adj/fsh_29586.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/English/cts/adj/fsh_29592.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/English/cts/adj/fsh_29601.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/English/cts/adj/fsh_29622.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/English/cts/adj/fsh_29630.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/English/cts/adj/fsh_29770.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/English/cts/adj/fsh_29782_2.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/English/cts/adj/fsh_29783.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/English/cts/adj/fsh_29786.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/English/wl/adj/AGGRESSIVEVOICEDAILY_20041101.1144.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/English/wl/adj/AGGRESSIVEVOICEDAILY_20041101.1806.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/English/wl/adj/AGGRESSIVEVOICEDAILY_20041116.1347.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/English/wl/adj/AGGRESSIVEVOICEDAILY_20041201.2313.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/English/wl/adj/AGGRESSIVEVOICEDAILY_20041203.1959.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/English/wl/adj/AGGRESSIVEVOICEDAILY_20041208.2133.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/English/wl/adj/AGGRESSIVEVOICEDAILY_20041215.2302.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/English/wl/adj/AGGRESSIVEVOICEDAILY_20041218.0146.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/English/wl/adj/AGGRESSIVEVOICEDAILY_20041218.1004.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/English/wl/adj/AGGRESSIVEVOICEDAILY_20041223.1449.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/English/wl/adj/AGGRESSIVEVOICEDAILY_20041226.1712.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/English/wl/adj/AGGRESSIVEVOICEDAILY_20050105.1344.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/English/wl/adj/AGGRESSIVEVOICEDAILY_20050106.1310.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/English/wl/adj/AGGRESSIVEVOICEDAILY_20050107.2012.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/English/wl/adj/AGGRESSIVEVOICEDAILY_20050109.1627.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/English/wl/adj/AGGRESSIVEVOICEDAILY_20050113.1400.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/English/wl/adj/AGGRESSIVEVOICEDAILY_20050114.1922.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/English/wl/adj/AGGRESSIVEVOICEDAILY_20050116.2149.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/English/wl/adj/AGGRESSIVEVOICEDAILY_20050124.1354.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/English/wl/adj/AGGRESSIVEVOICEDAILY_20050125.0136.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/English/wl/adj/AGGRESSIVEVOICEDAILY_20050203.1356.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/English/wl/adj/AGGRESSIVEVOICEDAILY_20050205.1954.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/English/wl/adj/AGGRESSIVEVOICEDAILY_20050208.1142.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/English/wl/adj/AGGRESSIVEVOICEDAILY_20050213.2123.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/English/wl/adj/AGGRESSIVEVOICEDAILY_20050224.1207.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/English/wl/adj/AGGRESSIVEVOICEDAILY_20050224.2252.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/English/wl/adj/BACONSREBELLION_20050123.1639.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/English/wl/adj/BACONSREBELLION_20050125.1108.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/English/wl/adj/BACONSREBELLION_20050127.1017.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/English/wl/adj/BACONSREBELLION_20050204.1326.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/English/wl/adj/BACONSREBELLION_20050205.1919.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/English/wl/adj/BACONSREBELLION_20050206.1345.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/English/wl/adj/BACONSREBELLION_20050209.0721.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/English/wl/adj/BACONSREBELLION_20050210.0728.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/English/wl/adj/BACONSREBELLION_20050214.0944.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/English/wl/adj/BACONSREBELLION_20050216.1536.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/English/wl/adj/BACONSREBELLION_20050216.1618.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/English/wl/adj/BACONSREBELLION_20050216.1632.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/English/wl/adj/BACONSREBELLION_20050217.0744.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/English/wl/adj/BACONSREBELLION_20050218.0848.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/English/wl/adj/BACONSREBELLION_20050218.1214.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/English/wl/adj/BACONSREBELLION_20050222.0817.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/English/wl/adj/BACONSREBELLION_20050222.1348.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/English/wl/adj/BACONSREBELLION_20050226.1317.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/English/wl/adj/BACONSREBELLION_20050227.1238.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/English/wl/adj/FLOPPINGACES_20041114.1240.039.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/English/wl/adj/FLOPPINGACES_20041115.1613.032.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/English/wl/adj/FLOPPINGACES_20041116.0833.027.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/English/wl/adj/FLOPPINGACES_20041228.0927.010.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/English/wl/adj/FLOPPINGACES_20041230.1844.003.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/English/wl/adj/FLOPPINGACES_20050101.2244.048.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/English/wl/adj/FLOPPINGACES_20050203.1953.038.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/English/wl/adj/FLOPPINGACES_20050217.1237.014.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/English/wl/adj/GETTINGPOLITICAL_20050105.0127.001.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/English/wl/adj/HEALINGIRAQ_20041108.1942.05.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/English/wl/adj/MARKBACKER_20041103.1300.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/English/wl/adj/MARKBACKER_20041108.1507.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/English/wl/adj/MARKBACKER_20041112.0707.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/English/wl/adj/MARKBACKER_20041117.0723.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/English/wl/adj/MARKBACKER_20041117.1107.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/English/wl/adj/MARKBACKER_20041119.1002.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/English/wl/adj/MARKBACKER_20041128.1641.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/English/wl/adj/MARKBACKER_20041202.0711.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/English/wl/adj/MARKBACKER_20041206.0733.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/English/wl/adj/MARKBACKER_20041217.1639.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/English/wl/adj/MARKBACKER_20041220.0919.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/English/wl/adj/MARKBACKER_20050103.0829.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/English/wl/adj/MARKBACKER_20050105.1526.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/English/wl/adj/MARKBACKER_20050105.1632.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/English/wl/adj/MARKBACKER_20050217.0647.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/English/wl/adj/MARKETVIEW_20041209.1401.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/English/wl/adj/MARKETVIEW_20041211.1845.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/English/wl/adj/MARKETVIEW_20041212.1447.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/English/wl/adj/MARKETVIEW_20041213.0722.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/English/wl/adj/MARKETVIEW_20041215.2128.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/English/wl/adj/MARKETVIEW_20041217.0801.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/English/wl/adj/MARKETVIEW_20041219.1509.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/English/wl/adj/MARKETVIEW_20041220.1537.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/English/wl/adj/MARKETVIEW_20050105.1901.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/English/wl/adj/MARKETVIEW_20050120.1641.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/English/wl/adj/MARKETVIEW_20050126.0711.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/English/wl/adj/MARKETVIEW_20050127.0716.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/English/wl/adj/MARKETVIEW_20050201.0748.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/English/wl/adj/MARKETVIEW_20050204.1322.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/English/wl/adj/MARKETVIEW_20050204.1337.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/English/wl/adj/MARKETVIEW_20050204.1736.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/English/wl/adj/MARKETVIEW_20050205.1358.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/English/wl/adj/MARKETVIEW_20050206.1951.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/English/wl/adj/MARKETVIEW_20050206.2009.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/English/wl/adj/MARKETVIEW_20050207.0746.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/English/wl/adj/MARKETVIEW_20050208.2033.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/English/wl/adj/MARKETVIEW_20050208.2059.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/English/wl/adj/MARKETVIEW_20050209.1923.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/English/wl/adj/MARKETVIEW_20050210.2138.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/English/wl/adj/MARKETVIEW_20050212.1607.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/English/wl/adj/MARKETVIEW_20050212.1717.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/English/wl/adj/MARKETVIEW_20050214.2115.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/English/wl/adj/MARKETVIEW_20050215.1858.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/English/wl/adj/MARKETVIEW_20050216.2120.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/English/wl/adj/MARKETVIEW_20050217.2115.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/English/wl/adj/MARKETVIEW_20050222.0729.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/English/wl/adj/MARKETVIEW_20050222.1919.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/English/wl/adj/MARKETVIEW_20050225.0541.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/English/wl/adj/MARKETVIEW_20050226.1444.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/English/wl/adj/MARKETVIEW_20050228.2211.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/English/wl/adj/OIADVANTAGE_20041224.1007.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/English/wl/adj/OIADVANTAGE_20050103.0944.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/English/wl/adj/OIADVANTAGE_20050105.0922.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/English/wl/adj/OIADVANTAGE_20050108.1323.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/English/wl/adj/OIADVANTAGE_20050109.1947.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/English/wl/adj/OIADVANTAGE_20050110.1009.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/English/wl/adj/OIADVANTAGE_20050203.1000.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/English/wl/adj/OIADVANTAGE_20050203.2102.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/English/wl/adj/OIADVANTAGE_20050204.1155.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/English/bn/adj/CNNHL_ENG_20030304_142751.10.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/English/bn/adj/CNNHL_ENG_20030312_150218.13.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/English/bn/adj/CNNHL_ENG_20030331_193419.9.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/English/bn/adj/CNNHL_ENG_20030402_133449.22.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/English/bn/adj/CNNHL_ENG_20030402_193443.5.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/English/bn/adj/CNNHL_ENG_20030403_133453.21.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/English/bn/adj/CNNHL_ENG_20030403_193455.30.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/English/bn/adj/CNNHL_ENG_20030407_193547.5.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/English/bn/adj/CNNHL_ENG_20030410_193626.13.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/English/bn/adj/CNNHL_ENG_20030411_230640.38.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/English/bn/adj/CNNHL_ENG_20030415_193729.5.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/English/bn/adj/CNNHL_ENG_20030416_133739.13.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/English/bn/adj/CNNHL_ENG_20030416_133739.9.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/English/bn/adj/CNNHL_ENG_20030416_193742.26.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/English/bn/adj/CNNHL_ENG_20030416_193742.7.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/English/bn/adj/CNNHL_ENG_20030416_230741.33.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/English/bn/adj/CNNHL_ENG_20030424_123502.25.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/English/bn/adj/CNNHL_ENG_20030425_183518.12.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/English/bn/adj/CNNHL_ENG_20030428_123600.14.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/English/bn/adj/CNNHL_ENG_20030429_220618.15.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/English/bn/adj/CNNHL_ENG_20030430_220712.37.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/English/bn/adj/CNNHL_ENG_20030505_220734.25.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/English/bn/adj/CNNHL_ENG_20030513_183907.5.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/English/bn/adj/CNNHL_ENG_20030513_220910.11.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/English/bn/adj/CNNHL_ENG_20030513_220910.32.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/English/bn/adj/CNNHL_ENG_20030519_124020.23.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/English/bn/adj/CNNHL_ENG_20030523_221118.14.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/English/bn/adj/CNNHL_ENG_20030603_230307.3.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/English/bn/adj/CNNHL_ENG_20030604_230238.5.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/English/bn/adj/CNNHL_ENG_20030609_133335.37.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/English/bn/adj/CNNHL_ENG_20030610_133347.6.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/English/bn/adj/CNNHL_ENG_20030610_230438.14.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/English/bn/adj/CNNHL_ENG_20030611_133445.24.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/English/bn/adj/CNNHL_ENG_20030616_230155.28.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/English/bn/adj/CNNHL_ENG_20030616_230155.7.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/English/bn/adj/CNNHL_ENG_20030618_230303.36.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/English/bn/adj/CNNHL_ENG_20030618_230303.6.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/English/bn/adj/CNNHL_ENG_20030624_133331.33.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/English/bn/adj/CNNHL_ENG_20030624_230338.34.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/English/bn/adj/CNNHL_ENG_20030625_230351.4.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/English/bn/adj/CNN_ENG_20030304_173120.16.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/English/bn/adj/CNN_ENG_20030305_170125.1.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/English/bn/adj/CNN_ENG_20030306_070606.18.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/English/bn/adj/CNN_ENG_20030306_083604.6.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/English/bn/adj/CNN_ENG_20030312_083725.3.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/English/bn/adj/CNN_ENG_20030312_223733.14.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/English/bn/adj/CNN_ENG_20030313_083739.0.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/English/bn/adj/CNN_ENG_20030318_140851.8.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/English/bn/adj/CNN_ENG_20030325_150531.10.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/English/bn/adj/CNN_ENG_20030325_220534.6.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/English/bn/adj/CNN_ENG_20030327_163556.20.apf.xml
# ...
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/Arabic/nw/adj/AFA20001218.1000.0034.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/Arabic/nw/adj/AFA20001221.1000.0032.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/Arabic/nw/adj/AFA20001221.1400.0071.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/Arabic/nw/adj/AFA20001222.1400.0085.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/Arabic/nw/adj/AFA20001222.1400.0086.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/Arabic/nw/adj/AFA20001223.1000.0044.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/Arabic/nw/adj/AFA20001223.1400.0054.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/Arabic/nw/adj/AFA20001225.0000.0009.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/Arabic/nw/adj/AFA20001225.1000.0038.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/Arabic/nw/adj/AFA20001227.1800.0106.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/Arabic/nw/adj/AFA20001229.1000.0032.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/Arabic/nw/adj/AFA20001229.1400.0070.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/Arabic/nw/adj/AFA20001229.1400.0071.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/Arabic/nw/adj/ALH20001005.0700.0064.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/Arabic/nw/adj/ALH20001014.1300.0083.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/Arabic/nw/adj/ALH20001014.1300.0085.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/Arabic/nw/adj/ALH20001014.1300.0089.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/Arabic/nw/adj/ALH20001014.1300.0100.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/Arabic/nw/adj/ALH20001014.1300.0106.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/Arabic/nw/adj/ALH20001014.1300.0111.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/Arabic/nw/adj/ALH20001014.1300.0116.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/Arabic/nw/adj/ALH20001015.0100.0005.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/Arabic/nw/adj/ALH20001015.0100.0018.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/Arabic/nw/adj/ALH20001015.0700.0045.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/Arabic/nw/adj/ALH20001015.1300.0060.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/Arabic/nw/adj/ALH20001015.1300.0077.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/Arabic/nw/adj/ALH20001015.1300.0085.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/Arabic/nw/adj/ALH20001015.1300.0102.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/Arabic/nw/adj/ALH20001016.0700.0036.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/Arabic/nw/adj/ALH20001016.0700.0041.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/Arabic/nw/adj/ALH20001016.0700.0048.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/Arabic/nw/adj/ALH20001017.0700.0030.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/Arabic/nw/adj/ALH20001017.0700.0050.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/Arabic/nw/adj/ALH20001017.0700.0061.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/Arabic/nw/adj/ALH20001017.1300.0087.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/Arabic/nw/adj/ALH20001018.0700.0021.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/Arabic/nw/adj/ALH20001019.1300.0101.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/Arabic/nw/adj/ALH20001020.1300.0091.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/Arabic/nw/adj/ALH20001024.0700.0048.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/Arabic/nw/adj/ALH20001025.0700.0034.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/Arabic/nw/adj/ALH20001025.0700.0047.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/Arabic/nw/adj/ALH20001028.1300.0072.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/Arabic/nw/adj/ALH20001028.1300.0082.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/Arabic/nw/adj/ALH20001030.1300.0104.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/Arabic/nw/adj/ALH20001031.1300.0069.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/Arabic/nw/adj/ALH20001105.1300.0083.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/Arabic/nw/adj/ALH20001107.0700.0027.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/Arabic/nw/adj/ALH20001112.1300.0062.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/Arabic/nw/adj/ALH20001114.0100.0020.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/Arabic/nw/adj/ALH20001114.0700.0024.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/Arabic/nw/adj/ALH20001114.0700.0028.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/Arabic/nw/adj/ALH20001114.0700.0030.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/Arabic/nw/adj/ALH20001114.1300.0064.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/Arabic/nw/adj/ALH20001114.1300.0074.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/Arabic/nw/adj/ALH20001114.1300.0084.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/Arabic/nw/adj/ALH20001114.1300.0095.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/Arabic/nw/adj/ALH20001114.1300.0096.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/Arabic/nw/adj/ALH20001114.1300.0097.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/Arabic/nw/adj/ALH20001115.0700.0047.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/Arabic/nw/adj/ALH20001115.0700.0050.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/Arabic/nw/adj/ALH20001115.1300.0075.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/Arabic/nw/adj/ALH20001115.1300.0078.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/Arabic/nw/adj/ALH20001115.1300.0083.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/Arabic/nw/adj/ALH20001115.1300.0091.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/Arabic/nw/adj/ALH20001117.1300.0075.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/Arabic/nw/adj/ALH20001120.0700.0043.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/Arabic/nw/adj/ALH20001123.0700.0014.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/Arabic/nw/adj/ALH20001123.0700.0023.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/Arabic/nw/adj/ALH20001124.1900.0127.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/Arabic/nw/adj/ALH20001125.0700.0024.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/Arabic/nw/adj/ALH20001128.1300.0081.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/Arabic/nw/adj/ALH20001201.1300.0071.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/Arabic/nw/adj/ALH20001201.1900.0126.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/Arabic/nw/adj/ALH20001209.0700.0031.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/Arabic/nw/adj/ALH20001210.1300.0101.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/Arabic/nw/adj/ALH20001217.0700.0032.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/Arabic/nw/adj/ALH20001218.0700.0031.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/Arabic/nw/adj/ALH20001218.1300.0096.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/Arabic/nw/adj/ALH20001218.1300.0117.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/Arabic/nw/adj/ALH20001223.1300.0082.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/Arabic/nw/adj/ALH20001229.1300.0055.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/Arabic/nw/adj/ANN20001013.0900.0052.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/Arabic/nw/adj/ANN20001019.0900.0066.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/Arabic/nw/adj/ANN20001107.0900.0039.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/Arabic/nw/adj/ANN20001118.1500.0101.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/Arabic/nw/adj/ANN20001120.1500.0090.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/Arabic/nw/adj/ANN20001124.1500.0090.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/Arabic/nw/adj/ANN20001125.0300.0003.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/Arabic/nw/adj/ANN20001125.0900.0084.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/Arabic/nw/adj/ANN20001125.2100.0155.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/Arabic/nw/adj/ANN20001128.0900.0064.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/Arabic/nw/adj/ANN20001130.1500.0072.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/Arabic/nw/adj/ANN20001201.1500.0092.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/Arabic/nw/adj/ANN20001201.2100.0146.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/Arabic/nw/adj/ANN20001207.0900.0035.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/Arabic/nw/adj/ANN20001212.0900.0071.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/Arabic/nw/adj/ANN20001213.0900.0063.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/Arabic/nw/adj/ANN20001223.0900.0102.apf.xml
# file_name= /Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/Arabic/nw/adj/ANN20001229.0900.0053.apf.xml
# Number of files processed for language=  Arabic  is=  403

# %% [markdown]
# ## Stanford CoreNLP Preprocessing:
# Generating the needed attributes:
#
# - words, lemmas, pos-tags
# - stanford-colcc

# %%
from nltk.parse.corenlp import CoreNLPDependencyParser, CoreNLPParser
dep_parser = CoreNLPDependencyParser(url='http://localhost:9001')
#parse, = dep_parser.raw_parse('The quick brown fox jumps over the lazy dog.')
sent = "No, they don\'t the 'suspicious evidence' is simply that\nArafat did not look particularly near death when he was\nremoved from his HQ"
parse, = dep_parser.raw_parse(sent)

# %%
print(parse)
# Out:
# defaultdict(<function DependencyGraph.__init__.<locals>.<lambda> at 0x1a1ef88510>,
#             {0: {'address': 0,
#                  'ctag': 'TOP',
#                  'deps': defaultdict(<class 'list'>, {'ROOT': [4]}),
#                  'feats': None,
#                  'head': None,
#                  'lemma': None,
#                  'rel': None,
#                  'tag': 'TOP',
#                  'word': None},
#              1: {'address': 1,
#                  'ctag': 'DT',
#                  'deps': defaultdict(<class 'list'>, {}),
#                  'feats': '_',
#                  'head': 4,
#                  'lemma': 'no',
#                  'rel': 'discourse',
#                  'tag': 'DT',
#                  'word': 'No'},
#              2: {'address': 2,
#                  'ctag': ',',
#                  'deps': defaultdict(<class 'list'>, {}),
#                  'feats': '_',
#                  'head': 4,
#                  'lemma': ',',
#                  'rel': 'punct',
#                  'tag': ',',
#                  'word': ','},
#              3: {'address': 3,
#                  'ctag': 'PRP',
#                  'deps': defaultdict(<class 'list'>, {}),
#                  'feats': '_',
#                  'head': 4,
#                  'lemma': 'they',
#                  'rel': 'nsubj',
#                  'tag': 'PRP',
#                  'word': 'they'},
#              4: {'address': 4,
#                  'ctag': 'VBP',
#                  'deps': defaultdict(<class 'list'>,
#                                      {'discourse': [1],
#                                       'neg': [5],
#                                       'nsubj': [3],
#                                       'punct': [2, 6]}),
#                  'feats': '_',
#                  'head': 0,
#                  'lemma': 'do',
#                  'rel': 'ROOT',
#                  'tag': 'VBP',
#                  'word': 'do'},
#              5: {'address': 5,
#                  'ctag': 'RB',
#                  'deps': defaultdict(<class 'list'>, {}),
#                  'feats': '_',
#                  'head': 4,
#                  'lemma': 'not',
#                  'rel': 'neg',
#                  'tag': 'RB',
#                  'word': "n't"},
#              6: {'address': 6,
#                  'ctag': '.',
#                  'deps': defaultdict(<class 'list'>, {}),
#                  'feats': '_',
#                  'head': 4,
#                  'lemma': '.',
#                  'rel': 'punct',
#                  'tag': '.',
#                  'word': '.'}})

# %%
print(parse.tokenBeginIndex)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-4-1c8c2e4a1ca5> in <module>
# ----> 1 print(parse.tokenBeginIndex)
#
# AttributeError: 'DependencyGraph' object has no attribute 'tokenBeginIndex'

# %%
def find_stanford_colcc(sent):
    parse, = dep_parser.raw_parse(sent)
    i = 0
    pos_tags = []
    words = []
    triples = []
    for part in parse.to_conll(4).split("\n"):
        if part != "":
            parts = part.split("\t")
            words.append(parts[0])
            pos_tags.append(parts[1])
            rel = parts[3].lower()
            gov = int(parts[2])-1
            dep = i
            i += 1

            triples.append(rel+"/dep="+str(dep)+"/gov="+str(gov))
    return triples, words, pos_tags

# %%
find_positions(sent)
# Out:
# {1: ['A', 0, 1],
#  2: ['statement', 2, 11],
#  3: ['issued', 12, 18],
#  4: ['at', 19, 21],
#  5: ['the', 22, 25],
#  6: ['two-day', 26, 33],
#  7: ['meeting', 34, 41],
#  8: ['of', 42, 44],
#  9: ['the', 45, 48],
#  10: ['EU', 49, 51],
#  11: ['foreign', 52, 59],
#  12: ['ministers', 60, 69],
#  13: ['called', 70, 76],
#  14: ['on', 77, 79],
#  15: ['Iran', 80, 84],
#  16: ['to', 85, 87],
#  17: ['conclude', 88, 96],
#  18: ['and', 97, 100],
#  19: ['implement', 101, 110],
#  20: ['urgently', 111, 119],
#  21: ['and', 120, 123],
#  22: ['unconditionally', 124, 139],
#  23: ['an', 140, 142],
#  24: ['additional', 143, 153],
#  25: ['protocol', 154, 162],
#  26: ['to', 163, 165],
#  27: ['the', 166, 169],
#  28: ['Nuclear', 170, 177],
#  29: ['Non', 178, 181],
#  30: ['-', 182, 183],
#  31: ['Proliferation', 184, 197],
#  32: ['Treaty', 198, 204],
#  33: ['allowing', 205, 213],
#  34: ['for', 214, 217],
#  35: ['short-notice', 218, 230],
#  36: ['inspections', 231, 242],
#  37: ['of', 243, 245],
#  38: ['suspected', 246, 255],
#  39: ['nuclear', 256, 263],
#  40: ['sites', 264, 269],
#  41: ['in', 270, 272],
#  42: ['the', 273, 276],
#  43: ['country', 277, 284]}

# %%
find_stanford_colcc(sent)
# Out:
# (['det/dep=0/gov=1',
#   'root/dep=1/gov=-1',
#   'acl/dep=2/gov=1',
#   'case/dep=3/gov=6',
#   'det/dep=4/gov=6',
#   'amod/dep=5/gov=6',
#   'nmod/dep=6/gov=2',
#   'case/dep=7/gov=11',
#   'det/dep=8/gov=11',
#   'compound/dep=9/gov=11',
#   'amod/dep=10/gov=11',
#   'nmod/dep=11/gov=6',
#   'acl/dep=12/gov=11',
#   'case/dep=13/gov=14',
#   'nmod/dep=14/gov=12',
#   'mark/dep=15/gov=16',
#   'xcomp/dep=16/gov=12',
#   'cc/dep=17/gov=16',
#   'conj/dep=18/gov=16',
#   'advmod/dep=19/gov=24',
#   'cc/dep=20/gov=19',
#   'conj/dep=21/gov=19',
#   'det/dep=22/gov=24',
#   'amod/dep=23/gov=24',
#   'dobj/dep=24/gov=16',
#   'case/dep=25/gov=28',
#   'det/dep=26/gov=28',
#   'amod/dep=27/gov=28',
#   'nmod/dep=28/gov=24',
#   'punct/dep=29/gov=24',
#   'compound/dep=30/gov=31',
#   'dep/dep=31/gov=24',
#   'acl/dep=32/gov=31',
#   'case/dep=33/gov=35',
#   'amod/dep=34/gov=35',
#   'nmod/dep=35/gov=32',
#   'case/dep=36/gov=39',
#   'amod/dep=37/gov=39',
#   'amod/dep=38/gov=39',
#   'nmod/dep=39/gov=35',
#   'case/dep=40/gov=42',
#   'det/dep=41/gov=42',
#   'nmod/dep=42/gov=39'],
#  ['A',
#   'statement',
#   'issued',
#   'at',
#   'the',
#   'two-day',
#   'meeting',
#   'of',
#   'the',
#   'EU',
#   'foreign',
#   'ministers',
#   'called',
#   'on',
#   'Iran',
#   'to',
#   'conclude',
#   'and',
#   'implement',
#   'urgently',
#   'and',
#   'unconditionally',
#   'an',
#   'additional',
#   'protocol',
#   'to',
#   'the',
#   'Nuclear',
#   'Non',
#   '-',
#   'Proliferation',
#   'Treaty',
#   'allowing',
#   'for',
#   'short-notice',
#   'inspections',
#   'of',
#   'suspected',
#   'nuclear',
#   'sites',
#   'in',
#   'the',
#   'country'],
#  ['DT',
#   'NN',
#   'VBN',
#   'IN',
#   'DT',
#   'JJ',
#   'NN',
#   'IN',
#   'DT',
#   'NNP',
#   'JJ',
#   'NNS',
#   'VBN',
#   'IN',
#   'NNP',
#   'TO',
#   'VB',
#   'CC',
#   'VB',
#   'RB',
#   'CC',
#   'RB',
#   'DT',
#   'JJ',
#   'NN',
#   'TO',
#   'DT',
#   'JJ',
#   'NN',
#   ':',
#   'NN',
#   'NNP',
#   'VBG',
#   'IN',
#   'JJ',
#   'NNS',
#   'IN',
#   'VBN',
#   'JJ',
#   'NNS',
#   'IN',
#   'DT',
#   'NN'])

# %%
print(parse.to_conll(4))
# Out:
# The	DT	2	det
# skeleton	NN	9	nsubjpass
# of	IN	6	case
# a	DT	6	det
# second	JJ	6	amod
# baby	NN	2	nmod
# has	VBZ	9	aux
# been	VBN	9	auxpass
# found	VBN	33	ccomp
# at	IN	14	case
# a	DT	14	det
# rural	JJ	14	amod
# Wisconsin	NNP	14	compound
# home	NN	9	nmod
# where	WRB	23	advmod
# a	DT	18	det
# 22-year-old	JJ	18	amod
# woman	NN	21	nmod:poss
# 's	POS	18	case
# dead	JJ	21	amod
# infant	NN	23	nsubjpass
# was	VBD	23	auxpass
# discovered	VBN	14	acl:relcl
# in	IN	28	case
# a	DT	28	det
# blue	JJ	28	amod
# plastic	NN	28	compound
# container	NN	23	nmod
# June	NNP	23	nmod:tmod
# 8	CD	29	nummod
# ,	,	33	punct
# officials	NNS	33	nsubj
# said	VBD	0	ROOT
# Monday	NNP	33	nmod:tmod
# .	.	33	punct

# %% [markdown]
# ## Save to json:

# %%
import json
from tqdm import tqdm

data_json = []
sent_json = []
for sent in tqdm(events_list_lang["English"]):
    sent_json.append(sent)
    data_sub = {}
    data_sub["golden-event-mentions"] = []
    entities_unique = {}
    for event in events_list_lang["English"][sent]:
        event_info = {}
        #(self, event_id, mention_id, type_, subtype, modality, polarity, genericity, 
        # tense, extent, scope, trig_text, trig_start, trig_end, arguments):
 
        event_info["trigger"] = {"start": event.trig_start, "end": event.trig_end, "text": event.trig_text}
        event_info["arguments"] = []
        for arg in event.arguments:
            arg_info = {"start": arg.start, "role": arg.role, "end": arg.end, "text": arg.text}
            event_info["arguments"].append(arg_info)
            
        event_info["id"] = event.event_id
        event_info["event_type"] = event.type_
        data_sub["golden-event-mentions"].append(event_info) 
        
        # Loading entities for that event and adding it to the list of entities
        for entity in event.entities:
            entities_unique.update({entity.id_:entity})
            
    data_sub["golden-entity-mentions"] = []
    for entity_id in entities_unique.keys():
        entity_info = {"phrase-type": entities_unique[entity_id].phrase_type, "end": entities_unique[entity_id].end, "text": entities_unique[entity_id].text, "entity-type": entities_unique[entity_id].entity_type, "start": entities_unique[entity_id].start, "id": entity_id}
        data_sub["golden-entity-mentions"].append(entity_info)
       
    triples, words, pos_tags = find_stanford_colcc(sent)
    data_json.append({"stanford-colcc": triples, "golden-entity-mentions": data_sub["golden-entity-mentions"], "words": words, "pos-tags": pos_tags, "golden-event-mentions": data_sub["golden-event-mentions"]})
# Out:
# 100%|██████████| 2590/2590 [00:48<00:00, 32.50it/s]

# %%
len(data_json)
# Out:
# 2590

# %%
data_json[0]
# Out:
# {'stanford-colcc': ['nsubj/dep=0/gov=5',
#   'aux/dep=1/gov=5',
#   'cop/dep=2/gov=5',
#   'det/dep=3/gov=5',
#   'compound/dep=4/gov=5',
#   'root/dep=5/gov=-1',
#   'case/dep=6/gov=9',
#   'det/dep=7/gov=9',
#   'compound/dep=8/gov=9',
#   'nmod/dep=9/gov=5',
#   'punct/dep=10/gov=9',
#   'amod/dep=11/gov=9',
#   'mark/dep=12/gov=13',
#   'advcl/dep=13/gov=11',
#   'dobj/dep=14/gov=13',
#   'case/dep=15/gov=18',
#   'det/dep=16/gov=18',
#   'compound/dep=17/gov=18',
#   'nmod/dep=18/gov=13'],
#  'golden-entity-mentions': [{'phrase-type': 'GPE:Population-Center',
#    'end': 11,
#    'text': 'Houston',
#    'entity-type': 'NAMPRE',
#    'start': 11,
#    'id': 'Austin-Grad-Community_20050212.2454-E1'},
#   {'phrase-type': 'ORG:Educational',
#    'end': 11,
#    'text': 'the Houston Center',
#    'entity-type': 'NOM',
#    'start': 11,
#    'id': 'Austin-Grad-Community_20050212.2454-E2'},
#   {'phrase-type': 'PER:Individual',
#    'end': 11,
#    'text': 'the Registration\nManager for the Houston Center',
#    'entity-type': 'NOM',
#    'start': 11,
#    'id': 'Austin-Grad-Community_20050212.2454-E29'}],
#  'words': ['She',
#   'will',
#   'be',
#   'the',
#   'Registration',
#   'Manager',
#   'for',
#   'the',
#   'Houston',
#   'Center',
#   ',',
#   'accountable',
#   'for',
#   'causing',
#   'registrations',
#   'into',
#   'the',
#   'Landmark',
#   'Forum'],
#  'pos-tags': ['PRP',
#   'MD',
#   'VB',
#   'DT',
#   'NNP',
#   'NNP',
#   'IN',
#   'DT',
#   'NNP',
#   'NNP',
#   ',',
#   'JJ',
#   'IN',
#   'VBG',
#   'NNS',
#   'IN',
#   'DT',
#   'NNP',
#   'NNP'],
#  'golden-event-mentions': [{'trigger': {'start': 3, 'end': 3, 'text': 'be'},
#    'arguments': [{'start': 1, 'role': 'Person', 'end': 1, 'text': 'She'},
#     {'start': 9, 'role': 'Place', 'end': 9, 'text': 'Houston'},
#     {'start': 8, 'role': 'Entity', 'end': 10, 'text': 'the Houston Center'},
#     {'start': 5,
#      'role': 'Position',
#      'end': 6,
#      'text': 'Registration\nManager'}],
#    'id': 'Austin-Grad-Community_20050212.2454-EV1',
#    'event_type': 'Personnel'},
#   {'trigger': {'start': 11, 'end': 11, 'text': 'Forum'},
#    'arguments': [{'start': 1, 'role': 'Place', 'end': 1, 'text': 'Houston'},
#     {'start': 10, 'role': 'Entity', 'end': 10, 'text': 'Landmark'}],
#    'id': 'Austin-Grad-Community_20050212.2454-EV3',
#    'event_type': 'Contact'}]}

# %% [markdown]
# ### Train/Dev/Test Split:

# %%
import random
random.shuffle(data_json)

# %%
with open('/Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/ace-05-splits/english/train.json', 'w') as outfile:
    json.dump(data_json[:2000], outfile)

# %%
with open('/Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/ace-05-splits/english/dev.json', 'w') as outfile:
    json.dump(data_json[2000:2250], outfile)

# %%
with open('/Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/ace-05-splits/english/test.json', 'w') as outfile:
    json.dump(data_json[2250:], outfile)

# %%
phrase_type, end, text, entity_type, start, id_

# %%
ev_example[1].trig_text
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-39-6b95a5913a15> in <module>
# ----> 1 ev_example[1].trig_text
#
# NameError: name 'ev_example' is not defined

# %%
events_list_lang["English"][6].scope
# Out:
# 'It will have to be snail mail), give her a call at the center, or\nsend her a fax and welcome her to our Center'
