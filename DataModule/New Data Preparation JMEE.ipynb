# %%
import glob
import xml.etree.ElementTree as ET
import re
import json
from nltk.tokenize import word_tokenize
import random
import math
from pycorenlp import StanfordCoreNLP

# %% [markdown]
# ## Class Definitions:

# %%
class Argument(object):
    def __init__(self, id_, text, role, start, end, entity_type):
        self.id_ = id_
        self.text = text
        self.role = role
        self.start = start
        self.end = end
        self.entity_type = entity_type

    def to_string(self):
        return "Argument: {id_ = " + self.id_ + ", text = " + self.text + ", role = " + self.role + ", start =" + str(self.start) + ", end =" + str(self.end) + "}"
        
    def __str__(self):
        return str(self.__dict__)
    
    def __eq__(self, other): 
        return self.__dict__ == other.__dict__
    
    def __hash__(self):
        return hash(self)

# %%
class Trigger(object):
    def __init__(self, start, text, end, id_, event_type):
        self.start = start
        self.text = text
        self.end = end
        self.id_ = id_
        self.event_type = event_type
        
    def __str__(self):
        return str(self.__dict__)
    
    def __eq__(self, other): 
        return self.__dict__ == other.__dict__
    
    def __hash__(self):
        return hash(self)

# %%
class Entity(object):
    def __init__(self, id_, text, entity_type, phrase_type, start, end):
        self.id_ = id_
        self.text = text
        self.entity_type = entity_type
        self.phrase_type = phrase_type
        self.start = start
        self.end = end

    def to_string(self):
        return "Entity: {id_ = " + self.id_ + ", text = " + self.text + ", entity_type = " + self.entity_type + ", phrase_type=" + self.phrase_type + ", start =" + str(self.start) + ", end =" + str(self.end) + "}"
    
    def __str__(self):
        return str(self.__dict__)
    
    def __eq__(self, other): 
        return self.__dict__ == other.__dict__
    
    def __hash__(self):
        return hash(self)

# %%
class Sentence(object):
    def __init__(self, text, start, end):
        self.text = text
        self.start = start
        self.end = end

    def to_string(self):
        return "Sentence: {text = " + self.text + ", start = " + self.start + ", end = " + self.end + "}"
    
    def __str__(self):
        return str(self.__dict__)

    def __eq__(self, other): 
        return self.__dict__ == other.__dict__
    
    def __hash__(self):
        return hash(self)

# %%
class Event(object):
    def __init__(self, event_id, mention_id, type_, subtype, modality, polarity, genericity, tense, extent, extent_start, extent_end, scope, scope_start, scope_end, trig_text, trig_start, trig_end, arguments, entities):
        self.event_id = event_id
        self.mention_id = mention_id
        self.type_ = type_
        self.subtype = subtype
        self.modality = modality
        self.polarity = polarity
        self.genericity = genericity
        self.tense = tense
        self.extent = extent
        self.extent_start = extent_start
        self.extent_end = extent_end
        self.scope = scope
        self.scope_start = scope_start
        self.scope_end = scope_end
        self.trig_text = trig_text
        self.trig_start = trig_start
        self.trig_end = trig_end
        self.arguments = arguments
        self.entities = entities


    def to_string(self):
        return "Event: { event_id = " + self.event_id + "mention_id = " + self.mention_id + ", type = " + self.type_ + ", subtype = " +self.subtype + ", modality = " \
               + self.modality + ", polarity = " + self.polarity + ", genericity= " + self.genericity + ", tense = " +\
               self.tense + ", extent = " +self.extent + ", scope = " + self.scope  + ", trigger = " + self.trig_text
    
    def __str__(self):
        return str(self.__dict__)
    
    def __eq__(self, other): 
        return self.__dict__ == other.__dict__
    
    def __hash__(self):
        return hash(self)

# %%
stanford = StanfordCoreNLP('http://localhost:9001')

# %%
### Get parse, conll dependencies, list of words, list of pos, dictionary of offsets: (penn-treebank, stanford-colcc, words, offset_start, offset_end):
def find_dep_words_pos_offsets(sent):
    output = stanford.annotate(sent, properties={'annotators': 'tokenize,ssplit,pos,depparse,parse', 'outputFormat' : 'json'})
    #print("output=", output)
    #print("sent= ", sent)
    penn_treebank = output['sentences'][0]['parse'].replace("\n", "")
    triples = []
    for part in output['sentences'][0]['enhancedPlusPlusDependencies']:
         triples.append(part['dep']+"/dep="+str(part['dependent']-1)+"/gov="+str(part['governor']-1))
          
    words = []
    words_dict = {}
    pos_tags = []
    offset_start_dic = {}
    offset_end_dic = {}
    for i, word in enumerate(output['sentences'][0]['tokens']):
        words.append(word["word"])
        pos_tags.append(word["pos"])
        offset_start_dic.update({word["characterOffsetBegin"]: word["index"]-1})
        offset_end_dic.update({word["characterOffsetEnd"]-1: word["index"]})
        words_dict.update({word["index"]-1: word["word"]})
        
    return penn_treebank, triples, words, pos_tags, offset_start_dic, offset_end_dic, words_dict

# %% [markdown]
# ## I. Annotation/Offset Extraction:

# %%
def extract_entity_info(entity, scope_start, scope_end, sent, words, offset_start_dic, offset_end_dic):
    entity_id = entity.attrib["ID"]
    phrase_type = entity.attrib["TYPE"] + ":" + entity.attrib["SUBTYPE"]
    entity_class = entity.attrib["CLASS"]
    #print("offset_start_dic:", offset_start_dic)
    #print("offset_end_dic:", offset_end_dic)
    entities = []
    for mention in entity.iter('entity_mention'):
        entity_type = mention.attrib["LDCTYPE"]
        for child in mention:
            if child.tag == "extent":
                for chil2 in child:
                    text = chil2.text
                    start = int(chil2.attrib["START"])
                    end = int(chil2.attrib["END"])
                    
        if scope_start <= start and  scope_end >= end:
            #print("offset_start_dic[start - scope_start]= ", offset_start_dic[start - scope_start])
            #print("offset_end_dic[end - scope_start]= ", offset_end_dic[end - scope_start])
            
            """
            if end - scope_start +1 in offset_end_dic:
                end_off = offset_end_dic[end - scope_start +1]
            elif end - scope_start + 2 in offset_end_dic:
                end_off = offset_end_dic[end - scope_start +2]
            elif end - scope_start in offset_end_dic:
                end_off = offset_end_dic[end - scope_start]
            elif end - scope_start - 1 in offset_end_dic:
                end_off = offset_end_dic[end - scope_start -1]
            elif end - scope_start - 2 in offset_end_dic:
                end_off = offset_end_dic[end - scope_start - 2]
                
            if start - scope_start +1 in offset_start_dic:
                start_off = offset_start_dic[start - scope_start +1]
            elif start - scope_start + 2 in offset_start_dic:
                start_off = offset_start_dic[start - scope_start +2]
            elif start - scope_start in offset_start_dic:
                start_off = offset_start_dic[start - scope_start]
            elif start - scope_start - 1 in offset_start_dic:
                start_off = offset_start_dic[start - scope_start -1]
            elif start - scope_start - 2 in offset_start_dic:
                start_off = offset_start_dic[start - scope_start - 2]  
                
            start_off = 0
            end_off = 2
            for i in range(-10, 10):
                if end - scope_start +i in offset_end_dic:
                    end_off = offset_end_dic[end - scope_start +i]

            for i in range(-10, 10):
                if start - scope_start +i in offset_start_dic:
                    start_off = offset_start_dic[start - scope_start +i]
            """
            try:
                try:
                    start_off = max(offset_start_dic[k] for k in offset_start_dic if k <= start - scope_start) #offset_start_dic[start - scope_start]
                except:
                    start_off = offset_start_dic[list(offset_start_dic.keys())[0]]
                #print("start_off:", start_off)
                try:
                    end_off = max(offset_end_dic[k] for k in offset_end_dic if k <= end - scope_start) #offset_end_dic[end - scope_start]
                except:
                    end_off = offset_end_dic[list(offset_start_dic.keys())[0]] + 1
                #print("end_off:", end_off)
                ent = Entity(entity_id, text, entity_type, phrase_type, start_off, end_off)
                entities.append(ent)

            except:
                print("Problematic sentence:", sent)
                print("words: ", words)
                print("offset_start_dic:", offset_start_dic)
                print("offset_end_dic:", offset_end_dic)
                print("entity:", text)
                print("start - scope_start:", start - scope_start)
                print("end - scope_start:", end - scope_start)
                continue
                
        
    return entities

# %%
def merge_two_dicts(x, y):
    z = x.copy()   # start with x's keys and values
    z.update(y)    # modifies z with y's keys and values & returns None
    return z

# %%
def extract_event_info(root, event):
    event_id = event.attrib["ID"]
    event_type = event.attrib["TYPE"]
    subtype = event.attrib["SUBTYPE"]
    modality = event.attrib["MODALITY"]
    polarity = event.attrib["POLARITY"]
    genericity = event.attrib["GENERICITY"]
    tense = event.attrib["TENSE"]

    ## Looking at event mentions
    for mention in event.iter('event_mention'):
        mention_id = mention.attrib["ID"]
        for child in mention:
            if child.tag == "extent":
                for chil2 in child:
                    extent = chil2.text.replace("&", "&amp;")
                    extent_start = int(chil2.attrib["START"])
                    extent_end = int(chil2.attrib["END"]) 
                    sent = Sentence(extent, extent_start, extent_end)
                    penn_treebank, triples, words, pos_tags, offset_start_dic, offset_end_dic, words_dict = find_dep_words_pos_offsets(extent)
                                    
            ## SCOPE USED AS SENTENCE
            elif child.tag == "ldc_scope":
                for chil2 in child:
                    scope = chil2.text
                    scope_start = int(chil2.attrib["START"])
                    scope_end = int(chil2.attrib["END"])
                
            ## TRIGGER EXTRACTION
            elif child.tag == "anchor":
                for chil2 in child:
                    trig_text = chil2.text
                    start = int(chil2.attrib["START"]) - extent_start
                    end = int(chil2.attrib["END"]) - extent_start
                    
                    """
                    start_off = 0
                    end_off = 2
                    for i in range(0, 10):
                        if end +i in offset_end_dic:
                            end_off = offset_end_dic[end +i]
                            
                    for i in range(0, 10):
                        if start +i in offset_start_dic:
                            start_off = offset_start_dic[start +i]
                    
                    
                    elif end + 2 in offset_end_dic:
                        print(offset_end_dic)
                        end_off = offset_end_dic[end +2]
                    elif end -1 in offset_end_dic:
                        end_off = offset_end_dic[end -1]
                    elif end in offset_end_dic:
                        end_off = offset_end_dic[end]
                    elif end +2 in offset_end_dic:
                        print(offset_end_dic)
                        end_off = offset_end_dic[end -2]
                    
                    if start +1 in offset_start_dic:
                        start_off = offset_start_dic[start +1]
                    elif start +2 in offset_start_dic:
                        start_off = offset_start_dic[start +2]
                    elif start  in offset_start_dic:
                        start_off = offset_start_dic[start ]
                    elif start - 1 in offset_start_dic:
                        start_off = offset_start_dic[start -1]
                    elif start+2 in offset_start_dic:
                        start_off = offset_start_dic[start -2]
                    
                        
                    
                
                    trig_start = start_off
                    trig_end = end_off
                    """
            
                    
                    try:
                    
                        try:
                            trig_start = max(offset_start_dic[k] for k in offset_start_dic if k <= start) #offset_start_dic[start]
                        except:
                            trig_start = offset_start_dic[list(offset_start_dic.keys())[0]]
                        try:
                            trig_end = max(offset_end_dic[k] for k in offset_end_dic if k <= end)
                        except:
                            trig_end = offset_end_dic[list(offset_start_dic.keys())[0]] + 1
                        
                        
                    except:
                        print("Problematic sentence:", sent)
                        print("words: ", words)
                        print("offset_start_dic:", offset_start_dic)
                        print("offset_end_dic:", offset_end_dic)
                        print("trig_text:", trig_text)
                        print("start:", start)
                        print("end:", end)
                        trig_start = -1
                        trig_end = -1
                        continue
                    
        
        ## Looking at entity mentions with that same event
        entities = []
        ent_id_role_dict = {}
        for entity in root.iter('entity'):
            ents = extract_entity_info(entity, extent_start, extent_end, sent, words, offset_start_dic, offset_end_dic)
            entities.extend(ents)
            if len(ents) > 0:
                ent_id_role_dict.update({ents[0].id_: ents[0].entity_type})
        
        arguments = []           
        for argument in mention.iter('event_mention_argument'):
            arg_id = argument.attrib["REFID"]
            role = argument.attrib["ROLE"]
            for child in argument:
                for chil2 in child:
                    arg_text = chil2.text
                    start = int(chil2.attrib["START"]) - extent_start
                    end = int(chil2.attrib["END"]) - extent_start
                    
                    """
                    start_off = 0
                    end_off = 2
                    for i in range(0, 10):
                        if end +i in offset_end_dic:
                            end_off = offset_end_dic[end +i]
                            
                    for i in range(0, 10):
                        if start +i in offset_start_dic:
                            start_off = offset_start_dic[start +i]
                    
                    
                    arg_start = start_off
                    arg_end = end_off
                    """
                    
                    try:
                        try:
                            arg_start = max(offset_start_dic[k] for k in offset_start_dic if k <= start) #offset_start_dic[start]
                        except:
                            arg_start = offset_start_dic[list(offset_start_dic.keys())[0]]
                        try:
                            arg_end = max(offset_end_dic[k] for k in offset_end_dic if k <= end) #offset_end_dic[end]
                        except:
                            arg_end = offset_end_dic[list(offset_start_dic.keys())[0]] + 1
                            
                        if "-".join(arg_id.split("-")[:-1]) in ent_id_role_dict:
                            type_ = ent_id_role_dict["-".join(arg_id.split("-")[:-1])]
                        elif arg_id in ent_id_role_dict:
                            type_ = ent_id_role_dict[arg_id]
                        else:
                            type_ = "--"
                        arg = Argument(arg_id, arg_text, role, arg_start, arg_end,type_) 

                        arguments.append(arg)
                    except:
                        print("Problematic sentence:", sent)
                        print("words: ", words)
                        print("offset_start_dic:", offset_start_dic)
                        print("offset_end_dic:", offset_end_dic)
                        print("argument:", arg_text)
                        continue
                    
                    
       
    ev = Event(event_id, mention_id, event_type, subtype, modality, polarity, genericity, tense, extent, extent_start, extent_end,
               scope, scope_start, scope_end, trig_text, trig_start, trig_end, arguments, entities)

    return sent, ev, penn_treebank, triples, words, pos_tags

# %%
from tqdm import tqdm
def extract_from_xml(root_path, files):
    events = {}
    #print(root_path + language + "/" + domain + "/adj/*.apf.xml")
    files_processed = 0
    for div in files: #tqdm(        
        # Get the event + argument annotation
        file_name = root_path + "English/"+ div.strip("\n") +".apf.xml"
        files_processed += 1
        tree = ET.parse(file_name, ET.XMLParser(encoding='utf-8'))
        root = tree.getroot()
        
        for event in root.iter('event'):
            sent, ev, penn_treebank, triples, words, pos_tags = extract_event_info(root, event)
            if sent.text not in events:
                events.update({sent.text: {"events":[ev], "penn_treebank" : penn_treebank, "triples": triples, "words": words, "pos_tags" :pos_tags}}) 
            else:
                ev_list = events[sent.text]["events"]
                ev_list.append(ev)
                events[sent.text]["events"] = ev_list
                
        print("---------------------------------------------------------")
    return events, files_processed

# %%
#root_path = "/Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/LDC2006T06/data/"
root_path = "/Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/Raw/ACE2005-TrainingData-V6.0/"

# %%
languages = [file_.split("/")[-1] for file_ in glob.glob(root_path + "*") if "Icon\r" not in file_]

# %% [markdown]
# ### Executing over the domains/languages:

# %%
files_splits = {}
with open("/Users/d22admin/Documents/JMEE/qi_filelist/new_filelist_ACE_training") as file:
    files_splits.update({"train": file.readlines()})

with open("/Users/d22admin/Documents/JMEE/qi_filelist/new_filelist_ACE_dev") as file:
    files_splits.update({"dev": file.readlines()})
    
with open("/Users/d22admin/Documents/JMEE/qi_filelist/new_filelist_ACE_test") as file:
    files_splits.update({"test": file.readlines()})

# %%
events_lang_splits = {}
files_num = 0
for split in ["train", "dev", "test"]:
    events, files_processed = extract_from_xml(root_path, files_splits[split])
    files_num += files_processed
    events_lang_splits.update({split: events})

    print("Number of files processed for language= ", language, " is= ", files_num)
# Out:
# ---------------------------------------------------------
# ---------------------------------------------------------
# Problematic sentence: {'text': 'Mr. Begala and Mr. Carville just donate', 'start': 1148, 'end': 1186}
# words:  ['Mr.', 'Begala', 'and', 'Mr.', 'Carville', 'just', 'donate']
# offset_start_dic: {0: 0, 4: 1, 11: 2, 15: 3, 19: 4, 28: 5, 33: 6}
# offset_end_dic: {2: 1, 9: 2, 13: 3, 17: 4, 26: 5, 31: 6, 38: 7}
# entity: Mr
# start - scope_start: 0
# end - scope_start: 1
# ---------------------------------------------------------
# ---------------------------------------------------------
# ---------------------------------------------------------
# ---------------------------------------------------------
# ---------------------------------------------------------
# ---------------------------------------------------------
# ---------------------------------------------------------
# ---------------------------------------------------------
# ---------------------------------------------------------
# ---------------------------------------------------------
# ---------------------------------------------------------
# ---------------------------------------------------------
# ---------------------------------------------------------
# ---------------------------------------------------------
# ---------------------------------------------------------
# ---------------------------------------------------------
# ---------------------------------------------------------
# ---------------------------------------------------------
# ---------------------------------------------------------
# ---------------------------------------------------------
# Problematic sentence: {'text': 'U.s.-led war', 'start': 470, 'end': 481}
# words:  ['U.s.-led', 'war']
# offset_start_dic: {0: 0, 9: 1}
# offset_end_dic: {7: 1, 11: 2}
# entity: U.s.-l
# start - scope_start: 0
# end - scope_start: 5
# Problematic sentence: {'text': 'U.s.-led war', 'start': 470, 'end': 481}
# words:  ['U.s.-led', 'war']
# offset_start_dic: {0: 0, 9: 1}
# offset_end_dic: {7: 1, 11: 2}
# argument: U.s.-l
# Problematic sentence: {'text': 'U.S.-led war', 'start': 1880, 'end': 1891}
# words:  ['U.S.-led', 'war']
# offset_start_dic: {0: 0, 9: 1}
# offset_end_dic: {7: 1, 11: 2}
# entity: U.S.-l
# start - scope_start: 0
# end - scope_start: 5
# Problematic sentence: {'text': 'U.S.-led war', 'start': 1880, 'end': 1891}
# words:  ['U.S.-led', 'war']
# offset_start_dic: {0: 0, 9: 1}
# offset_end_dic: {7: 1, 11: 2}
# argument: U.S.-l
# ---------------------------------------------------------
# ---------------------------------------------------------
# ---------------------------------------------------------
# Problematic sentence: {'text': 'U.S. forces moving ever closer to Baghdad', 'start': 130, 'end': 170}
# words:  ['U.S.', 'forces', 'moving', 'ever', 'closer', 'to', 'Baghdad']
# offset_start_dic: {0: 0, 5: 1, 12: 2, 19: 3, 24: 4, 31: 5, 34: 6}
# offset_end_dic: {3: 1, 10: 2, 17: 3, 22: 4, 29: 5, 32: 6, 40: 7}
# entity: U.S
# start - scope_start: 0
# end - scope_start: 2
# ---------------------------------------------------------
# ---------------------------------------------------------
# Problematic sentence: {'text': 'U.S. forces rolling closer and closer to Baghdad', 'start': 147, 'end': 194}
# words:  ['U.S.', 'forces', 'rolling', 'closer', 'and', 'closer', 'to', 'Baghdad']
# offset_start_dic: {0: 0, 5: 1, 12: 2, 20: 3, 27: 4, 31: 5, 38: 6, 41: 7}
# offset_end_dic: {3: 1, 10: 2, 18: 3, 25: 4, 29: 5, 36: 6, 39: 7, 47: 8}
# entity: U.S
# start - scope_start: 0
# end - scope_start: 2
# ---------------------------------------------------------
# Problematic sentence: {'text': 'U.S
# offset_start_dic: {0: 0, 4: 1, 9: 2, 17: 3, 22: 4, 25: 5, 31: 6, 35: 7, 38: 8, 43: 9, 49: 10, 56: 11, 61: 12, 67: 13, 73: 14, 76: 15, 83: 16}
# offset_end_dic: {2: 1, 7: 2, 15: 3, 20: 4, 23: 5, 29: 6, 33: 7, 36: 8, 41: 9, 47: 10, 54: 11, 59: 12, 65: 13, 71: 14, 74: 15, 81: 16, 86: 17}
# entity: mr
# start - scope_start: 0
# end - scope_start: 1
# ---------------------------------------------------------
# ---------------------------------------------------------
# ---------------------------------------------------------
# ---------------------------------------------------------
# ---------------------------------------------------------
# ---------------------------------------------------------
# ---------------------------------------------------------
# ---------------------------------------------------------
# ---------------------------------------------------------
# ---------------------------------------------------------
# ---------------------------------------------------------
# ---------------------------------------------------------
# ---------------------------------------------------------
# ---------------------------------------------------------
# ---------------------------------------------------------
# ---------------------------------------------------------
# ---------------------------------------------------------
# ---------------------------------------------------------
# ---------------------------------------------------------
# ---------------------------------------------------------
# ---------------------------------------------------------
# ---------------------------------------------------------
# ---------------------------------------------------------
# ---------------------------------------------------------
# ---------------------------------------------------------
# ---------------------------------------------------------
# ---------------------------------------------------------
# ---------------------------------------------------------
# Problematic sentence: {'text': 'israeli-american-\npalestinian summit', 'start': 2286, 'end': 2321}
# words:  ['israeli-american', '-', 'palestinian', 'summit']
# offset_start_dic: {0: 0, 16: 1, 18: 2, 30: 3}
# offset_end_dic: {15: 1, 16: 2, 28: 3, 35: 4}
# entity: israeli
# start - scope_start: 0
# end - scope_start: 6
# Problematic sentence: {'text': 'israeli-american-\npalestinian summit', 'start': 2286, 'end': 2321}
# words:  ['israeli-american', '-', 'palestinian', 'summit']
# offset_start_dic: {0: 0, 16: 1, 18: 2, 30: 3}
# offset_end_dic: {15: 1, 16: 2, 28: 3, 35: 4}
# argument: israeli
# ---------------------------------------------------------
# ---------------------------------------------------------
# ---------------------------------------------------------
# ---------------------------------------------------------
# ---------------------------------------------------------
# ---------------------------------------------------------
# ---------------------------------------------------------
# ---------------------------------------------------------
# ---------------------------------------------------------
# ---------------------------------------------------------
# ---------------------------------------------------------
# ---------------------------------------------------------
# ---------------------------------------------------------
# ---------------------------------------------------------
# ---------------------------------------------------------
# ---------------------------------------------------------
# ---------------------------------------------------------
# ---------------------------------------------------------
# ---------------------------------------------------------
# ---------------------------------------------------------
# ---------------------------------------------------------
# Problematic sentence: {'text': 'u.s. military action', 'start': 257, 'end': 276}
# words:  ['u.s.', 'military', 'action']
# offset_start_dic: {0: 0, 5: 1, 14: 2}
# offset_end_dic: {3: 1, 12: 2, 19: 3}
# entity: u.s
# start - scope_start: 0
# end - scope_start: 2
# ---------------------------------------------------------
# ---------------------------------------------------------
# ---------------------------------------------------------
# ---------------------------------------------------------
# ---------------------------------------------------------
# ---------------------------------------------------------
# Problematic sentence: {'text': 'mr.\ntonkin and sylvester stl loan was paid', 'start': 1501, 'end': 1542}
# words:  ['mr.', 'tonkin', 'and', 'sylvester', 'stl', 'loan', 'was', 'paid']
# offset_start_dic: {0: 0, 4: 1, 11: 2, 15: 3, 25: 4, 29: 5, 34: 6, 38: 7}
# offset_end_dic: {2: 1, 9: 2, 13: 3, 23: 4, 27: 5, 32: 6, 36: 7, 41: 8}
# entity: mr
# start - scope_start: 0
# end - scope_start: 1
# ---------------------------------------------------------
# ---------------------------------------------------------
# ---------------------------------------------------------
# ---------------------------------------------------------
# ---------------------------------------------------------
# ---------------------------------------------------------
# ---------------------------------------------------------
# ---------------------------------------------------------
# ---------------------------------------------------------
# ---------------------------------------------------------
# ---------------------------------------------------------
# ---------------------------------------------------------
# ---------------------------------------------------------
# ---------------------------------------------------------
# ---------------------------------------------------------
# ---------------------------------------------------------
# ---------------------------------------------------------
# ---------------------------------------------------------
# ---------------------------------------------------------
# ---------------------------------------------------------
# ---------------------------------------------------------
# ---------------------------------------------------------
# ---------------------------------------------------------
# ---------------------------------------------------------
# ---------------------------------------------------------
# ---------------------------------------------------------
# ---------------------------------------------------------
# ---------------------------------------------------------
# ---------------------------------------------------------
# ---------------------------------------------------------
# ---------------------------------------------------------
# ---------------------------------------------------------
# ---------------------------------------------------------
# ---------------------------------------------------------
# ---------------------------------------------------------
# ---------------------------------------------------------
# ---------------------------------------------------------
# ---------------------------------------------------------
# ---------------------------------------------------------
# ---------------------------------------------------------
# ---------------------------------------------------------
# ---------------------------------------------------------
# ---------------------------------------------------------
# ---------------------------------------------------------
# ---------------------------------------------------------
# Problematic sentence: {'text': "U.S. forces in\nnorthern Iraq to open another front against Saddam's forces", 'start': 3307, 'end': 3380}
# words:  ['U.S.', 'forces', 'in', 'northern', 'Iraq', 'to', 'open', 'another', 'front', 'against', 'Saddam', "'s", 'forces']
# offset_start_dic: {0: 0, 5: 1, 12: 2, 15: 3, 24: 4, 29: 5, 32: 6, 37: 7, 45: 8, 51: 9, 59: 10, 65: 11, 68: 12}
# offset_end_dic: {3: 1, 10: 2, 13: 3, 22: 4, 27: 5, 30: 6, 35: 7, 43: 8, 49: 9, 57: 10, 64: 11, 66: 12, 73: 13}
# entity: U.S
# start - scope_start: 0
# end - scope_start: 2
# Problematic sentence: {'text': 'U.S. warplanes struck Iraqi ground\ntroops and bunkers in northern Iraq', 'start': 1236, 'end': 1305}
# words:  ['U.S.', 'warplanes', 'struck', 'Iraqi', 'ground', 'troops', 'and', 'bunkers', 'in', 'northern', 'Iraq']
# offset_start_dic: {0: 0, 5: 1, 15: 2, 22: 3, 28: 4, 35: 5, 42: 6, 46: 7, 54: 8, 57: 9, 66: 10}
# offset_end_dic: {3: 1, 13: 2, 20: 3, 26: 4, 33: 5, 40: 6, 44: 7, 52: 8, 55: 9, 64: 10, 69: 11}
# entity: U.S
# start - scope_start: 0
# end - scope_start: 2
# Problematic sentence: {'text': 'U.

# entity: U.S
# start - scope_start: 0
# end - scope_start: 2
# ---------------------------------------------------------
# ---------------------------------------------------------
# Problematic sentence: {'text': 'U.S.-led attack', 'start': 2091, 'end': 2105}
# words:  ['U.S.-led', 'attack']
# offset_start_dic: {0: 0, 9: 1}
# offset_end_dic: {7: 1, 14: 2}
# entity: U.S
# start - scope_start: 0
# end - scope_start: 2
# Problematic sentence: {'text': 'U.S.-led attack', 'start': 2091, 'end': 2105}
# words:  ['U.S.-led', 'attack']
# offset_start_dic: {0: 0, 9: 1}
# offset_end_dic: {7: 1, 14: 2}
# argument: U.S
# Problematic sentence: {'text': 'U.S.- led\nwar', 'start': 1459, 'end': 1471}
# words:  ['U.S.', '-', 'led', 'war']
# offset_start_dic: {0: 0, 4: 1, 6: 2, 10: 3}
# offset_end_dic: {3: 1, 4: 2, 8: 3, 12: 4}
# entity: U.S
# start - scope_start: 0
# end - scope_start: 2
# Problematic sentence: {'text': 'U.S.- led\nwar', 'start': 1459, 'end': 1471}
# words:  ['U.S.', '-', 'led', 'war']
# ...
# ---------------------------------------------------------
# ---------------------------------------------------------
# ---------------------------------------------------------
# ---------------------------------------------------------
# ---------------------------------------------------------
# ---------------------------------------------------------
# ---------------------------------------------------------
# ---------------------------------------------------------
# ---------------------------------------------------------
# ---------------------------------------------------------
# ---------------------------------------------------------
# ---------------------------------------------------------
# ---------------------------------------------------------
# ---------------------------------------------------------
# ---------------------------------------------------------
# ---------------------------------------------------------
# ---------------------------------------------------------
# ---------------------------------------------------------
# ---------------------------------------------------------
# Problematic sentence: {'text': 'US-led military campaign in Iraq', 'start': 288, 'end': 319}
# words:  ['US-led', 'military', 'campaign', 'in', 'Iraq']
# offset_start_dic: {0: 0, 7: 1, 16: 2, 25: 3, 28: 4}
# offset_end_dic: {5: 1, 14: 2, 23: 3, 26: 4, 31: 5}
# entity: US
# start - scope_start: 0
# end - scope_start: 1
# Problematic sentence: {'text': 'US-led military campaign in Iraq', 'start': 288, 'end': 319}
# words:  ['US-led', 'military', 'campaign', 'in', 'Iraq']
# offset_start_dic: {0: 0, 7: 1, 16: 2, 25: 3, 28: 4}
# offset_end_dic: {5: 1, 14: 2, 23: 3, 26: 4, 31: 5}
# argument: US
# ---------------------------------------------------------
# Problematic sentence: {'text': 'US-led invasion', 'start': 3364, 'end': 3378}
# words:  ['US-led', 'invasion']
# offset_start_dic: {0: 0, 7: 1}
# offset_end_dic: {5: 1, 14: 2}
# entity: US
# start - scope_start: 0
# end - scope_start: 1
# Problematic sentence: {'text': 'US-led invasion', 'start': 3364, 'end': 3378}
# words:  ['US-led', 'invasion']
# offset_start_dic: {0: 0, 7: 1}
# offset_end_dic: {5: 1, 14: 2}
# argument: US
# ---------------------------------------------------------
# Number of files processed for language=  Arabic  is=  529
# Problematic sentence: {'text': 'U.S. troops to go to\nIraq', 'start': 2843, 'end': 2867}
# words:  ['U.S.', 'troops', 'to', 'go', 'to', 'Iraq']
# offset_start_dic: {0: 0, 5: 1, 12: 2, 15: 3, 18: 4, 21: 5}
# offset_end_dic: {3: 1, 10: 2, 13: 3, 16: 4, 19: 5, 24: 6}
# entity: U.S
# start - scope_start: 0
# end - scope_start: 2
# ---------------------------------------------------------
# ---------------------------------------------------------
# Problematic sentence: {'text': 'U.S.-led forces were able to press farther north after\ndefeating Iraqi Republican Guard units at Karbala and Kut', 'start': 513, 'end': 624}
# words:  ['U.S.-led', 'forces', 'were', 'able', 'to', 'press', 'farther', 'north', 'after', 'defeating', 'Iraqi', 'Republican', 'Guard', 'units', 'at', 'Karbala', 'and', 'Kut']
# offset_start_dic: {0: 0, 9: 1, 16: 2, 21: 3, 26: 4, 29: 5, 35: 6, 43: 7, 49: 8, 55: 9, 65: 10, 71: 11, 82: 12, 88: 13, 94: 14, 97: 15, 105: 16, 109: 17}
# offset_end_dic: {7: 1, 14: 2, 19: 3, 24: 4, 27: 5, 33: 6, 41: 7, 47: 8, 53: 9, 63: 10, 69: 11, 80: 12, 86: 13, 92: 14, 95: 15, 103: 16, 107: 17, 111: 18}
# entity: U.S
# start - scope_start: 0
# end - scope_start: 2
# Problematic sentence: {'text': 'U.
# words:  ['US-led', 'attacks']
# offset_start_dic: {0: 0, 7: 1}
# offset_end_dic: {5: 1, 13: 2}
# entity: US
# start - scope_start: 0
# end - scope_start: 1
# Problematic sentence: {'text': 'US-led attacks', 'start': 428, 'end': 441}
# words:  ['US-led', 'attacks']
# offset_start_dic: {0: 0, 7: 1}
# offset_end_dic: {5: 1, 13: 2}
# argument: US
# ---------------------------------------------------------
# ---------------------------------------------------------
# ---------------------------------------------------------
# Number of files processed for language=  Arabic  is=  559
# ---------------------------------------------------------
# Problematic sentence: {'text': 'US-British invasion', 'start': 2593, 'end': 2611}
# words:  ['US-British', 'invasion']
# offset_start_dic: {0: 0, 11: 1}
# offset_end_dic: {9: 1, 18: 2}
# entity: US
# start - scope_start: 0
# end - scope_start: 1
# Problematic sentence: {'text': 'US-British invasion', 'start': 2593, 'end': 2611}
# words:  ['US-British', 'invasion']
# offset_start_dic: {0: 0, 11: 1}
# offset_end_dic: {9: 1, 18: 2}
# argument: US
# ---------------------------------------------------------
# ---------------------------------------------------------
# ---------------------------------------------------------
# Problematic sentence: {'text': 'US-led campaign in\nIraq', 'start': 353, 'end': 375}
# words:  ['US-led', 'campaign', 'in', 'Iraq']
# offset_start_dic: {0: 0, 7: 1, 16: 2, 19: 3}
# offset_end_dic: {5: 1, 14: 2, 17: 3, 22: 4}
# entity: US
# start - scope_start: 0
# end - scope_start: 1
# Problematic sentence: {'text': 'US-led campaign in\nIraq', 'start': 353, 'end': 375}
# words:  ['US-led', 'campaign', 'in', 'Iraq']
# offset_start_dic: {0: 0, 7: 1, 16: 2, 19: 3}
# offset_end_dic: {5: 1, 14: 2, 17: 3, 22: 4}
# argument: US
# ---------------------------------------------------------
# ---------------------------------------------------------
# ---------------------------------------------------------
# ---------------------------------------------------------
# ---------------------------------------------------------
# ---------------------------------------------------------
# ---------------------------------------------------------
# ---------------------------------------------------------
# ---------------------------------------------------------
# ---------------------------------------------------------
# ---------------------------------------------------------
# ---------------------------------------------------------
# ---------------------------------------------------------
# ---------------------------------------------------------
# ---------------------------------------------------------
# ---------------------------------------------------------
# ---------------------------------------------------------
# ---------------------------------------------------------
# ---------------------------------------------------------
# ---------------------------------------------------------
# ---------------------------------------------------------
# ---------------------------------------------------------
# ---------------------------------------------------------
# ---------------------------------------------------------
# ---------------------------------------------------------
# ---------------------------------------------------------
# ---------------------------------------------------------
# ---------------------------------------------------------
# ---------------------------------------------------------
# ---------------------------------------------------------
# Problematic sentence: {'text': 'U.S. troops for a war against Iraq', 'start': 4260, 'end': 4293}
# words:  ['U.S.', 'troops', 'for', 'a', 'war', 'against', 'Iraq']
# offset_start_dic: {0: 0, 5: 1, 12: 2, 16: 3, 18: 4, 22: 5, 30: 6}
# offset_end_dic: {3: 1, 10: 2, 14: 3, 16: 4, 20: 5, 28: 6, 33: 7}
# entity: U.S
# start - scope_start: 0
# end - scope_start: 2
# ---------------------------------------------------------
# Problematic sentence: {'text': 'U.S.-led war', 'start': 494, 'end': 505}
# words:  ['U.S.-led', 'war']
# offset_start_dic: {0: 0, 9: 1}
# offset_end_dic: {7: 1, 11: 2}
# entity: U.S
# start - scope_start: 0
# end - scope_start: 2
# Problematic sentence: {'text': 'U.S.-led war', 'start': 494, 'end': 505}
# words:  ['U.S.-led', 'war']
# offset_start_dic: {0: 0, 9: 1}
# offset_end_dic: {7: 1, 11: 2}
# argument: U.S
# ---------------------------------------------------------
# Problematic sentence: {'text': "Paris-based Vivendi Universal entertains bids for Universal Studios,\nUniversal's theme parks and other entertainment assets", 'start': 262, 'end': 384}
# words:  ['Paris-based', 'Vivendi', 'Universal', 'entertains', 'bids', 'for', 'Universal', 'Studios', ',', 'Universal', "'s", 'theme', 'parks', 'and', 'other', 'entertainment', 'assets']
# offset_start_dic: {0: 0, 12: 1, 20: 2, 30: 3, 41: 4, 46: 5, 50: 6, 60: 7, 67: 8, 69: 9, 78: 10, 81: 11, 87: 12, 93: 13, 97: 14, 103: 15, 117: 16}
# offset_end_dic: {10: 1, 18: 2, 28: 3, 39: 4, 44: 5, 48: 6, 58: 7, 66: 8, 67: 9, 77: 10, 79: 11, 85: 12, 91: 13, 95: 14, 101: 15, 115: 16, 122: 17}
# entity: Paris
# start - scope_start: 0
# end - scope_start: 4

# entity: U.S
# start - scope_start: 0
# end - scope_start: 2
# Problematic sentence: {'text': 'U.S. and British troops had encountered little\nresistance, even when they seized nearby Umm Qasr', 'start': 1945, 'end': 2040}
# words:  ['U.S.', 'and', 'British', 'troops', 'had', 'encountered', 'little', 'resistance', ',', 'even', 'when', 'they', 'seized', 'nearby', 'Umm', 'Qasr']
# offset_start_dic: {0: 0, 5: 1, 9: 2, 17: 3, 24: 4, 28: 5, 40: 6, 47: 7, 57: 8, 59: 9, 64: 10, 69: 11, 74: 12, 81: 13, 88: 14, 92: 15}
# offset_end_dic: {3: 1, 7: 2, 15: 3, 22: 4, 26: 5, 38: 6, 45: 7, 56: 8, 57: 9, 62: 10, 67: 11, 72: 12, 79: 13, 86: 14, 90: 15, 95: 16}
# entity: U.S
# start - scope_start: 0
# end - scope_start: 2
# ---------------------------------------------------------
# ---------------------------------------------------------
# ---------------------------------------------------------
# Number of files processed for language=  Arabic  is=  599

# %%
events_lang_splits["train"]
# Out:
# {'الهجمات من الإسلامويين': {'events': [<__main__.Event at 0x1a19d01ac8>],
#   'penn_treebank': '(ROOT  (X    (NP      (QP (CD الهجمات) (CD من))      (NN الإسلامويين))))',
#   'triples': ['ROOT/dep=2/gov=-1',
#    'compound/dep=0/gov=1',
#    'nummod/dep=1/gov=2'],
#   'words': ['الهجمات', 'من', 'الإسلامويين'],
#   'pos_tags': ['CD', 'CD', 'NN']},
#  'يتسلق جندي عراقي ينزف من جرح في بطنه انقاض بناية': {'events': [<__main__.Event at 0x1a1a2dee10>],
#   'penn_treebank': '(ROOT  (NP    (NP      (NP        (QP (SYM يتسلق) (CD جندي) (CD عراقي)))      (NP (CD ينزف) (NN من)))    (NP      (NP (CD جرح) (NN في))      (NP        (QP (CD بطنه) (CD انقاض))        (CD بناية)))))',
#   'triples': ['ROOT/dep=2/gov=-1',
#    'dep/dep=0/gov=2',
#    'compound/dep=1/gov=2',
#    'nummod/dep=3/gov=4',
#    'dep/dep=4/gov=2',
#    'nummod/dep=5/gov=6',
#    'dep/dep=6/gov=2',
#    'compound/dep=7/gov=8',
#    'nummod/dep=8/gov=9',
#    'dep/dep=9/gov=6'],
#   'words': ['يتسلق',
#    'جندي',
#    'عراقي',
#    'ينزف',
#    'من',
#    'جرح',
#    'في',
#    'بطنه',
#    'انقاض',
#    'بناية'],
#   'pos_tags': ['SYM', 'CD', 'CD', 'CD', 'NN', 'CD', 'NN', 'CD', 'CD', 'CD']},
#  'مقابلة مع رويترز في موقع التصوير يوم الجمعة "لعل الأمر ينطبق\nعلى أي حرب لكنه (الفيلم) عما جرى بالعراق خاصة في بغداد': {'events': [<__main__.Event at 0x1a1bae4c50>],
#   'penn_treebank': '(ROOT  (NP    (NP      (NP (NN مقابلة))      (SBAR        (S          (VP (SYM مع)            (NP (CD رويترز) (CD في))))))    (NP      (NP        (QP (CD موقع) (CD التصوير))        (QP (CD يوم) (CD الجمعة)))      (`` ``)      (NP        (NP          (NP (FW لعل) (FW الأمر) (FW ينطبق) (FW على) (FW أي) (FW حرب))          (NP            (NP (NN لكنه))            (PRN (-LRB- -LRB-)              (NP (NN الفيلم))              (-RRB- -RRB-))))        (NP          (NP            (QP (CD عما) (CD جرى))            (QP (CD بالعراق) (CD خاصة)))          (NP (NN في) (CD بغداد)))))))',
#   'triples': ['ROOT/dep=0/gov=-1',
#    'dep/dep=1/gov=3',
#    'nummod/dep=2/gov=3',
#    'acl:relcl/dep=3/gov=0',
#    'compound/dep=4/gov=5',
#    'nummod/dep=5/gov=7',
#    'compound/dep=6/gov=7',
#    'dep/dep=7/gov=0',
#    'punct/dep=8/gov=7',
#    'compound/dep=9/gov=14',
#    'compound/dep=10/gov=14',
#    'compound/dep=11/gov=14',
#    'compound/dep=12/gov=14',
#    'compound/dep=13/gov=14',
#    'dep/dep=14/gov=7',
#    'dep/dep=15/gov=14',
#    'punct/dep=16/gov=17',
#    'appos/dep=17/gov=15',
#    'punct/dep=18/gov=17',
#    'compound/dep=19/gov=20',
#    'nummod/dep=20/gov=22',
#    'compound/dep=21/gov=22',
#    'dep/dep=22/gov=14',
#    'dep/dep=23/gov=22',
#    'nummod/dep=24/gov=23'],
#   'words': ['مقابلة',
#    'مع',
#    'رويترز',
#    'في',
#    'موقع',
#    'التصوير',
#    'يوم',
#    'الجمعة',
#    '``',
#    'لعل',
#    'الأمر',
#    'ينطبق',
#    'على',
#    'أي',
#    'حرب',
#    'لكنه',
#    '-LRB-',
#    'الفيلم',
#    '-RRB-',
#    'عما',
#    'جرى',
#    'بالعراق',
#    'خاصة',
#    'في',
#    'بغداد'],
#   'pos_tags': ['NN',
#    'SYM',
#    'CD',
#    'CD',
#    'CD',
#    'CD',
#    'CD',
#    'CD',
#    '``',
#    'FW',
#    'FW',
#    'FW',
#    'FW',
#    'FW',
#    'FW',
#    'NN',
#    '-LRB-',
#    'NN',
#    '-RRB-',
#    'CD',
#    'CD',
#    'CD',
#    'CD',
#    'NN',
#    'CD']},
#  'جندي عراقي ينزف من جرح في بطنه انقاض بناية\nدمرها القصف في بغداد': {'events': [<__main__.Event at 0x1a18e937f0>],
#   'penn_treebank': '(ROOT  (FRAG    (X      (NP        (NP (CD جندي) (CD عراقي))        (NP (CD ينزف) (NN من)))      (NP (CD جرح) (NN في))      (NP        (NP (CD بطنه) (CD انقاض))        (NP          (NP            (QP (CD بناية) (CD دمرها)))          (NP (CD القصف) (NN في)))))    (NP (CD بغداد))))',
#   'triples': ['ROOT/dep=12/gov=-1',
#    'nummod/dep=0/gov=1',
#    'dep/dep=1/gov=7',
#    'nummod/dep=2/gov=3',
#    'dep/dep=3/gov=1',
#    'nummod/dep=4/gov=5',
#    'dep/dep=5/gov=7',
#    'nummod/dep=6/gov=7',
#    'dep/dep=7/gov=12',
#    'compound/dep=8/gov=9',
#    'dep/dep=9/gov=7',
#    'nummod/dep=10/gov=11',
#    'dep/dep=11/gov=9'],
#   'words': ['جندي',
#    'عراقي',
#    'ينزف',
#    'من',
#    'جرح',
#    'في',
#    'بطنه',
#    'انقاض',
#    'بناية',
#    'دمرها',
#    'القصف',
#    'في',
#    'بغداد'],
#   'pos_tags': ['CD',
#    'CD',
#    'CD',
#    'NN',
#    'CD',
#    'NN',
#    'CD',
#    'CD',
#    'CD',
#    'CD',
#    'CD',
#    'NN',
#    'CD']},
#  'أقرا لك رسالة': {'events': [<__main__.Event at 0x1a1bcad7b8>],
#   'penn_treebank': '(ROOT  (FRAG    (NP (CD أقرا))    (NP (CD لك) (CD رسالة))))',
#   'triples': ['ROOT/dep=0/gov=-1', 'nummod/dep=1/gov=2', 'dep/dep=2/gov=0'],
#   'words': ['أقرا', 'لك', 'رسالة'],
#   'pos_tags': ['CD', 'CD', 'CD']},
#  'كتبتموه': {'events': [<__main__.Event at 0x1a17c1a7f0>],
#   'penn_treebank': '(ROOT  (NP (NN كتبتموه)))',
#   'triples': ['ROOT/dep=0/gov=-1'],
#   'words': ['كتبتموه'],
#   'pos_tags': ['NN']},
#  'داوود القطان والذي اغتيل هو وزوجته ووالد': {'events': [<__main__.Event at 0x1a1e007400>],
#   'penn_treebank': '(ROOT  (NP    (NP      (NP        (QP (SYM داوود) (CD القطان) (CD والذي)))      (NP (CD اغتيل) (NN هو)))    (NP (CD وزوجته) (CD ووالد))))',
#   'triples': ['ROOT/dep=2/gov=-1',
#    'dep/dep=0/gov=2',
#    'compound/dep=1/gov=2',
#    'nummod/dep=3/gov=4',
#    'dep/dep=4/gov=2',
#    'nummod/dep=5/gov=6',
#    'dep/dep=6/gov=2'],
#   'words': ['داوود', 'القطان', 'والذي', 'اغتيل', 'هو', 'وزوجته', 'ووالد'],
#   'pos_tags': ['SYM', 'CD', 'CD', 'CD', 'NN', 'CD', 'CD']},
#  'رسالة من الفقي د\nالمُرسِل Dawood Sami\nالمُرسَل إليه hassan blasm\nالموضــوع Re: هلو\nالتـاريخ 1/2/2005 1:47:57 PM': {'events': [<__main__.Event at 0x1a1cee7e80>],
#   'penn_treebank': '(ROOT  (NP    (NP (NN رسالة))    (X      (X        (X (SYM من))        (NP          (NP            (QP (SYM الفقي) (SYM د) (CD المُرسِل)))          (PP (NNP Dawood)            (NP (NNP Sami) (CD المُرسَل)))))      (NP        (NP (CD إليه) (NN hassan))        (NP (NN blasm) (CD الموضــوع) (NNP Re))))    (: :)    (NP      (NP        (QP (CD هلو) (CD التـاريخ)))      (NP (CD 1/2/2005) (CD 1:47:57) (NNS PM)))))',
#   'triples': ['ROOT/dep=0/gov=-1',
#    'dep/dep=1/gov=4',
#    'dep/dep=2/gov=4',
#    'dep/dep=3/gov=4',
#    'dep/dep=4/gov=9',
#    'dep/dep=5/gov=6',
#    'nmod/dep=6/gov=4',
#    'nummod/dep=7/gov=6',
#    'nummod/dep=8/gov=9',
#    'dep/dep=9/gov=0',
#    'compound/dep=10/gov=12',
#    'nummod/dep=11/gov=12',
#    'dep/dep=12/gov=9',
#    'punct/dep=13/gov=0',
#    'compound/dep=14/gov=15',
#    'dep/dep=15/gov=0',
#    'nummod/dep=16/gov=18',
#    'nummod/dep=17/gov=18',
#    'dep/dep=18/gov=15'],
#   'words': ['رسالة',
#    'من',
#    'الفقي',
#    'د',
#    'المُرسِل',
#    'Dawood',
#    'Sami',
#    'المُرسَل',
#    'إليه',
#    'hassan',
#    'blasm',
#    'الموضــوع',
#    'Re',
#    ':',
#    'هلو',
#    'التـاريخ',
#    '1/2/2005',
#    '1:47:57',
#    'PM'],
#   'pos_tags': ['NN',
#    'SYM',
#    'SYM',
#    'SYM',
#    'CD',
#    'NNP',
#    'NNP',
#    'CD',
#    'CD',
#    'NN',
#    'NN',
#    'CD',
#    'NNP',
#    ':',
#    'CD',
#    'CD',
#    'CD',
#    'CD',
#    'NNS']},
#  'ماتت راقصة البالية في إنكلترا': {'events': [<__main__.Event at 0x1a1aed6160>],
#   'penn_treebank': '(ROOT  (NP    (NP (CD ماتت))    (NP      (NP        (QP (CD راقصة) (CD البالية)))      (NP (NN في) (CD إنكلترا)))))',
#   'triples': ['ROOT/dep=0/gov=-1',
#    'compound/dep=1/gov=2',
#    'dep/dep=2/gov=0',
#    'dep/dep=3/gov=2',
#    'nummod/dep=4/gov=3'],
#   'words': ['ماتت', 'راقصة', 'البالية', 'في', 'إنكلترا'],
#   'pos_tags': ['CD', 'CD', 'CD', 'NN', 'CD']},
#  'فكتبوا إلى برناردشو': {'events': [<__main__.Event at 0x1a1a03d518>],
#   'penn_treebank': '(ROOT  (FRAG    (NP (NN فكتبوا))    (NP (CD إلى) (CD برناردشو))))',
#   'triples': ['ROOT/dep=0/gov=-1', 'nummod/dep=1/gov=2', 'dep/dep=2/gov=0'],
#   'words': ['فكتبوا', 'إلى', 'برناردشو'],
#   'pos_tags': ['NN', 'CD', 'CD']},
#  'فكتب إليهم ي': {'events': [<__main__.Event at 0x1a1a0c9d30>],
#   'penn_treebank': '(ROOT  (NP    (NP (CD فكتب))    (VP (CD إليهم))    (X (SYM ي))))',
#   'triples': ['ROOT/dep=0/gov=-1', 'dep/dep=1/gov=0', 'dep/dep=2/gov=0'],
#   'words': ['فكتب', 'إليهم', 'ي'],
#   'pos_tags': ['CD', 'CD', 'SYM']},
#  'رسالة الفنان السينمائي العراقي قاسم حول الى نادي الفيل': {'events': [<__main__.Event at 0x1a1a0c9588>],
#   'penn_treebank': '(ROOT  (NP    (NP      (NP        (QP (SYM رسالة) (CD الفنان) (CD السينمائي)))      (NP (CD العراقي) (CD قاسم)))    (NP      (NP        (QP (CD حول) (CD الى)))      (NP (CD نادي) (CD الفيل)))))',
#   'triples': ['ROOT/dep=2/gov=-1',
#    'dep/dep=0/gov=2',
#    'compound/dep=1/gov=2',
#    'nummod/dep=3/gov=4',
#    'dep/dep=4/gov=2',
#    'compound/dep=5/gov=6',
#    'dep/dep=6/gov=2',
#    'nummod/dep=7/gov=8',
#    'dep/dep=8/gov=6'],
#   'words': ['رسالة',
#    'الفنان',
#    'السينمائي',
#    'العراقي',
#    'قاسم',
#    'حول',
#    'الى',
#    'نادي',
#    'الفيل'],
#   'pos_tags': ['SYM', 'CD', 'CD', 'CD', 'CD', 'CD', 'CD', 'CD', 'CD']},
#  'إنكلترا تواصلت الإجتماعات في محاولة\nلإعادة مجد البالية ولم يفلحوا': {'events': [<__main__.Event at 0x1a19cd4e80>],
#   'penn_treebank': '(ROOT  (NP    (NP      (NP        (QP (CD إنكلترا) (CD تواصلت)))      (NP (CD الإجتماعات) (NN في)))    (NP      (NP        (QP (CD محاولة) (CD لإعادة))        (QP (CD مجد) (CD البالية)))      (NP (CD ولم) (NN يفلحوا)))))',
#   'triples': ['ROOT/dep=1/gov=-1',
#    'compound/dep=0/gov=1',
#    'nummod/dep=2/gov=3',
#    'dep/dep=3/gov=1',
#    'compound/dep=4/gov=5',
#    'nummod/dep=5/gov=7',
#    'compound/dep=6/gov=7',
#    'dep/dep=7/gov=1',
#    'nummod/dep=8/gov=9',
#    'dep/dep=9/gov=7'],
#   'words': ['إنكلترا',
#    'تواصلت',
#    'الإجتماعات',
#    'في',
#    'محاولة',
#    'لإعادة',
#    'مجد',
#    'البالية',
#    'ولم',
#    'يفلحوا'],
#   'pos_tags': ['CD', 'CD', 'CD', 'NN', 'CD', 'CD', 'CD', 'CD', 'CD', 'NN']},
#  'رسالة الشاعر والروائي علي بدر الى اصدقاء الفيل': {'events': [<__main__.Event at 0x1a1852a5c0>],
#   'penn_treebank': '(ROOT  (NP    (NP      (NP        (QP (SYM رسالة) (CD الشاعر) (CD والروائي)))      (NP (CD علي)))    (NP      (NP        (QP (CD بدر) (CD الى)))      (NP (NN اصدقاء) (CD الفيل)))))',
#   'triples': ['ROOT/dep=2/gov=-1',
#    'dep/dep=0/gov=2',
#    'compound/dep=1/gov=2',
#    'dep/dep=3/gov=2',
#    'compound/dep=4/gov=5',
#    'dep/dep=5/gov=2',
#    'dep/dep=6/gov=5',
#    'nummod/dep=7/gov=6'],
#   'words': ['رسالة',
#    'الشاعر',
#    'والروائي',
#    'علي',
#    'بدر',
#    'الى',
#    'اصدقاء',
#    'الفيل'],
#   'pos_tags': ['SYM', 'CD', 'CD', 'CD', 'CD', 'CD', 'NN', 'CD']},
#  'التقيت في تونس مدير مهرجان القارات الثلاث في فرنسا': {'events': [<__main__.Event at 0x1a1a0a1e10>],
#   'penn_treebank': '(ROOT  (NP    (NP      (NP (NN التقيت))      (SBAR        (S          (VP (SYM في)            (NP (CD تونس) (CD مدير) (NN مهرجان))))))    (NP      (NP        (QP (CD القارات) (CD الثلاث)))      (NP (NN في) (CD فرنسا)))))',
#   'triples': ['ROOT/dep=0/gov=-1',
#    'dep/dep=1/gov=4',
#    'nummod/dep=2/gov=4',
#    'nummod/dep=3/gov=4',
#    'acl:relcl/dep=4/gov=0',
#    'compound/dep=5/gov=6',
#    'dep/dep=6/gov=0',
#    'dep/dep=7/gov=6',
#    'nummod/dep=8/gov=7'],
#   'words': ['التقيت',
#    'في',
#    'تونس',
#    'مدير',
#    'مهرجان',
#    'القارات',
#    'الثلاث',
#    'في',
#    'فرنسا'],
#   'pos_tags': ['NN', 'SYM', 'CD', 'CD', 'NN', 'CD', 'CD', 'NN', 'CD']},
#  'هجرة أهالي الجنوب إلى بغداد': {'events': [<__main__.Event at 0x1a1c203cc0>],
#   'penn_treebank': '(ROOT  (NP    (NP (CD هجرة))    (NP      (NP (CD أهالي) (NN الجنوب))      (NP        (QP (CD إلى) (CD بغداد))))))',
#   'triples': ['ROOT/dep=0/gov=-1',
#    'nummod/dep=1/gov=2',
#    'dep/dep=2/gov=0',
#    'compound/dep=3/gov=4',
#    'dep/dep=4/gov=2'],
#   'words': ['هجرة', 'أهالي', 'الجنوب', 'إلى', 'بغداد'],
#   'pos_tags': ['CD', 'CD', 'NN', 'CD', 'CD']},
#  'السينمائي العراقي الشهير المقيم\nفي باريس منذ ثلاثين سنة قد عاد الى بغداد': {'events': [<__main__.Event at 0x1a1bdbb940>],
#   'penn_treebank': '(ROOT  (FRAG    (X      (NP        (NP (CD السينمائي) (CD العراقي))        (NP (CD الشهير) (CD المقيم)))      (NP (NN في) (CD باريس))      (NP        (NP (CD منذ))        (NP          (NP            (QP (CD ثلاثين) (CD سنة)))          (NP (NN قد) (CD عاد)))))    (NP (CD الى) (CD بغداد))))',
#   'triples': ['ROOT/dep=12/gov=-1',
#    'nummod/dep=0/gov=1',
#    'dep/dep=1/gov=6',
#    'nummod/dep=2/gov=3',
#    'dep/dep=3/gov=1',
#    'dep/dep=4/gov=6',
#    'nummod/dep=5/gov=4',
#    'dep/dep=6/gov=12',
#    'compound/dep=7/gov=8',
#    'dep/dep=8/gov=6',
#    'dep/dep=9/gov=8',
#    'nummod/dep=10/gov=9',
#    'nummod/dep=11/gov=12'],
#   'words': ['السينمائي',
#    'العراقي',
#    'الشهير',
#    'المقيم',
#    'في',
#    'باريس',
#    'منذ',
#    'ثلاثين',
#    'سنة',
#    'قد',
#    'عاد',
#    'الى',
#    'بغداد'],
#   'pos_tags': ['CD',
#    'CD',
#    'CD',
#    'CD',
#    'NN',
#    'CD',
#    'CD',
#    'CD',
#    'CD',
#    'NN',
#    'CD',
#    'CD',
#    'CD']},
#  'يهجم بها على الشبح': {'events': [<__main__.Event at 0x1a1bc426a0>],
#   'penn_treebank': '(ROOT  (FRAG    (NP (CD يهجم) (CD بها))    (NP (CD على) (CD الشبح))))',
#   'triples': ['ROOT/dep=1/gov=-1',
#    'nummod/dep=0/gov=1',
#    'nummod/dep=2/gov=3',
#    'dep/dep=3/gov=1'],
#   'words': ['يهجم', 'بها', 'على', 'الشبح'],
#   'pos_tags': ['CD', 'CD', 'CD', 'CD']},
#  'يصيبه': {'events': [<__main__.Event at 0x1a1bc42710>],
#   'penn_treebank': '(ROOT  (X (SYM يصيبه)))',
#   'triples': ['ROOT/dep=0/gov=-1'],
#   'words': ['يصيبه'],
#   'pos_tags': ['SYM']},
#  'السجين، قنينة عرق مكسورة ويهجم بها على الشبح\nويصيبه بطعنات': {'events': [<__main__.Event at 0x1a1a0738d0>],
#   'penn_treebank': '(ROOT  (NP    (NP      (NP (NN السجين))      (SBAR        (S          (VP (SYM ،)            (NP (CD قنينة) (CD عرق) (NN مكسورة))))))    (NP      (NP        (QP (CD ويهجم) (CD بها))        (QP (CD على) (CD الشبح)))      (NP (CD ويصيبه) (NN بطعنات)))))',
#   'triples': ['ROOT/dep=0/gov=-1',
#    'dep/dep=1/gov=4',
#    'nummod/dep=2/gov=4',
#    'nummod/dep=3/gov=4',
#    'acl:relcl/dep=4/gov=0',
#    'compound/dep=5/gov=6',
#    'nummod/dep=6/gov=8',
#    'compound/dep=7/gov=8',
#    'dep/dep=8/gov=0',
#    'nummod/dep=9/gov=10',
#    'dep/dep=10/gov=8'],
#   'words': ['السجين',
#    '،',
#    'قنينة',
#    'عرق',
#    'مكسورة',
#    'ويهجم',
#    'بها',
#    'على',
#    'الشبح',
#    'ويصيبه',
#    'بطعنات'],
#   'pos_tags': ['NN',
#    'SYM',
#    'CD',
#    'CD',
#    'NN',
#    'CD',
#    'CD',
#    'CD',
#    'CD',
#    'CD',
#    'NN']},
#  'عودتك إلى المنزل': {'events': [<__main__.Event at 0x1a19bf15c0>],
#   'penn_treebank': '(ROOT  (X    (NP      (QP (CD عودتك) (CD إلى))      (NN المنزل))))',
#   'triples': ['ROOT/dep=2/gov=-1',
#    'compound/dep=0/gov=1',
#    'nummod/dep=1/gov=2'],
#   'words': ['عودتك', 'إلى', 'المنزل'],
#   'pos_tags': ['CD', 'CD', 'NN']},
#  'تركضون نحو البيوت': {'events': [<__main__.Event at 0x1a19a6f630>],
#   'penn_treebank': '(ROOT  (X    (NP      (QP (CD تركضون) (CD نحو))      (NN البيوت))))',
#   'triples': ['ROOT/dep=2/gov=-1',
#    'compound/dep=0/gov=1',
#    'nummod/dep=1/gov=2'],
#   'words': ['تركضون', 'نحو', 'البيوت'],
#   'pos_tags': ['CD', 'CD', 'NN']},
#  'وتدخل المدرسة أول يوم': {'events': [<__main__.Event at 0x1a1937e6d8>],
#   'penn_treebank': '(ROOT  (FRAG    (X      (X (SYM وتدخل))      (NP (CD المدرسة)))    (NP (CD أول) (CD يوم))))',
#   'triples': ['ROOT/dep=3/gov=-1',
#    'dep/dep=0/gov=1',
#    'dep/dep=1/gov=3',
#    'nummod/dep=2/gov=3'],
#   'words': ['وتدخل', 'المدرسة', 'أول', 'يوم'],
#   'pos_tags': ['SYM', 'CD', 'CD', 'CD']},
#  'أخرج': {'events': [<__main__.Event at 0x1a19a6fbe0>],
#   'penn_treebank': '(ROOT  (X (SYM أخرج)))',
#   'triples': ['ROOT/dep=0/gov=-1'],
#   'words': ['أخرج'],
#   'pos_tags': ['SYM']},
#  'تلك الأيام حين كان جنود الاحتلال يداهمون\nمدرستنا ويطلقون النار': {'events': [<__main__.Event at 0x1a19058eb8>],
#   'penn_treebank': '(ROOT  (NP    (NP (CD تلك) (CD الأيام))    (NP      (NP        (QP (CD حين) (CD كان))        (QP (CD جنود) (CD الاحتلال)))      (NP        (QP (CD يداهمون) (CD مدرستنا))        (QP (CD ويطلقون) (CD النار))))))',
#   'triples': ['ROOT/dep=1/gov=-1',
#    'nummod/dep=0/gov=1',
#    'compound/dep=2/gov=3',
#    'nummod/dep=3/gov=5',
#    'compound/dep=4/gov=5',
#    'dep/dep=5/gov=1',
#    'compound/dep=6/gov=7',
#    'nummod/dep=7/gov=9',
#    'compound/dep=8/gov=9',
#    'dep/dep=9/gov=5'],
#   'words': ['تلك',
#    'الأيام',
#    'حين',
#    'كان',
#    'جنود',
#    'الاحتلال',
#    'يداهمون',
#    'مدرستنا',
#    'ويطلقون',
#    'النار'],
#   'pos_tags': ['CD', 'CD', 'CD', 'CD', 'CD', 'CD', 'CD', 'CD', 'CD', 'CD']},
#  'انسحاب الجنود من المدن\nالفلسطينية الرئيسية': {'events': [<__main__.Event at 0x1a19a6fa58>],
#   'penn_treebank': '(ROOT  (NP    (NP (CD انسحاب) (CD الجنود) (NN من))    (NP      (NP        (QP (CD المدن) (CD الفلسطينية)))      (NP (CD الرئيسية)))))',
#   'triples': ['ROOT/dep=2/gov=-1',
#    'nummod/dep=0/gov=2',
#    'nummod/dep=1/gov=2',
#    'compound/dep=3/gov=4',
#    'dep/dep=4/gov=2',
#    'dep/dep=5/gov=4'],
#   'words': ['انسحاب', 'الجنود', 'من', 'المدن', 'الفلسطينية', 'الرئيسية'],
#   'pos_tags': ['CD', 'CD', 'NN', 'CD', 'CD', 'CD']},
#  'باستشهاد\nالفتى محمد شبل صغير': {'events': [<__main__.Event at 0x1a1d11c710>],
#   'penn_treebank': '(ROOT  (NP    (NP (CD باستشهاد))    (NP      (NP        (QP (CD الفتى) (CD محمد)))      (NP (CD شبل) (CD صغير)))))',
#   'triples': ['ROOT/dep=0/gov=-1',
#    'compound/dep=1/gov=2',
#    'dep/dep=2/gov=0',
#    'nummod/dep=3/gov=4',
#    'dep/dep=4/gov=2'],
#   'words': ['باستشهاد', 'الفتى', 'محمد', 'شبل', 'صغير'],
#   'pos_tags': ['CD', 'CD', 'CD', 'CD', 'CD']},
#  'يستشهد': {'events': [<__main__.Event at 0x1a1d11c908>],
#   'penn_treebank': '(ROOT  (NP (NN يستشهد)))',
#   'triples': ['ROOT/dep=0/gov=-1'],
#   'words': ['يستشهد'],
#   'pos_tags': ['NN']},
#  'ذلك الفتى يسكن في الحي الذي أعيش\nفيه، أبيّ ابن الست سنوات قتل وهو في بيته وعلى سريره أتت رصاصة': {'events': [<__main__.Event at 0x1a1d11c240>],
#   'penn_treebank': '(ROOT  (FRAG    (X      (X        (NP          (NP (CD ذلك) (CD الفتى))          (NP            (NP (CD يسكن) (NN في))            (NP              (QP (CD الحي) (CD الذي))              (QP (CD أعيش) (CD فيه)))))        (NP (NN ،) (CD أبيّ))        (NP          (NP (CD ابن) (CD الست))          (NP (CD سنوات) (CD قتل))))      (NP        (NP (CD وهو) (NN في))        (NP          (NP            (QP (CD بيته) (CD وعلى)))          (NP (CD سريره)))))    (NP (CD أتت) (CD رصاصة))))',
#   'triples': ['ROOT/dep=20/gov=-1',
#    'nummod/dep=0/gov=1',
#    'dep/dep=1/gov=11',
#    'nummod/dep=2/gov=3',
#    'dep/dep=3/gov=1',
#    'compound/dep=4/gov=5',
#    'nummod/dep=5/gov=7',
#    'compound/dep=6/gov=7',
#    'dep/dep=7/gov=3',
#    'dep/dep=8/gov=11',
#    'nummod/dep=9/gov=8',
#    'nummod/dep=10/gov=11',
#    'dep/dep=11/gov=15',
#    'nummod/dep=12/gov=13',
#    'dep/dep=13/gov=11',
#    'nummod/dep=14/gov=15',
#    'dep/dep=15/gov=20',
#    'compound/dep=16/gov=17',
#    'dep/dep=17/gov=15',
#    'dep/dep=18/gov=17',
#    'nummod/dep=19/gov=20'],
#   'words': ['ذلك',
#    'الفتى',
#    'يسكن',
#    'في',
#    'الحي',
#    'الذي',
#    'أعيش',
#    'فيه',
#    '،',
#    'أبيّ',
#    'ابن',
#    'الست',
#    'سنوات',
#    'قتل',
#    'وهو',
#    'في',
#    'بيته',
#    'وعلى',
#    'سريره',
#    'أتت',
#    'رصاصة'],
#   'pos_tags': ['CD',
#    'CD',
#    'CD',
#    'NN',
#    'CD',
#    'CD',
#    'CD',
#    'CD',
#    'NN',
#    'CD',
#    'CD',
#    'CD',
#    'CD',
#    'CD',
#    'CD',
#    'NN',
#    'CD',
#    'CD',
#    'CD',
#    'CD',
#    'CD']},
#  'منع التجول علينا ياههههههه لقد نسينا (ممنوع التجول والي يطلع من\nبيت': {'events': [<__main__.Event at 0x1a19058898>],
#   'penn_treebank': '(ROOT  (NP    (NP      (NP        (QP (CD منع) (CD التجول)))      (NP (CD علينا) (CD ياههههههه)))    (NP      (NP (CD لقد) (NN نسينا))      (-LRB- -LRB-)      (NP        (NP          (QP (CD ممنوع) (CD التجول))          (QP (CD والي) (CD يطلع)))        (NP (NN من) (CD بيت))))))',
#   'triples': ['ROOT/dep=1/gov=-1',
#    'compound/dep=0/gov=1',
#    'nummod/dep=2/gov=3',
#    'dep/dep=3/gov=1',
#    'nummod/dep=4/gov=5',
#    'dep/dep=5/gov=1',
#    'punct/dep=6/gov=5',
#    'compound/dep=7/gov=8',
#    'nummod/dep=8/gov=10',
#    'compound/dep=9/gov=10',
#    'dep/dep=10/gov=5',
#    'dep/dep=11/gov=10',
#    'nummod/dep=12/gov=11'],
#   'words': ['منع',
#    'التجول',
#    'علينا',
#    'ياههههههه',
#    'لقد',
#    'نسينا',
#    '-LRB-',
#    'ممنوع',
#    'التجول',
#    'والي',
#    'يطلع',
#    'من',
#    'بيت'],
#   'pos_tags': ['CD',
#    'CD',
#    'CD',
#    'CD',
#    'CD',
#    'NN',
#    '-LRB-',
#    'CD',
#    'CD',
#    'CD',
#    'CD',
#    'NN',
#    'CD']},
#  'اغتالوا أبيّ\nابن الست سنوات وهو في بيته وعلى سريره': {'events': [<__main__.Event at 0x1a1d1c4208>],
#   'penn_treebank': '(ROOT  (NP    (NP      (NP        (QP (CD اغتالوا) (CD أبيّ))        (QP (CD ابن) (CD الست)))      (NP        (QP (CD سنوات) (CD وهو))        (NN في)))    (NP      (NP        (QP (CD بيته) (CD وعلى)))      (NP (CD سريره)))))',
#   'triples': ['ROOT/dep=3/gov=-1',
#    'compound/dep=0/gov=1',
#    'nummod/dep=1/gov=3',
#    'compound/dep=2/gov=3',
#    'compound/dep=4/gov=5',
#    'nummod/dep=5/gov=6',
#    'dep/dep=6/gov=3',
#    'compound/dep=7/gov=8',
#    'dep/dep=8/gov=3',
#    'dep/dep=9/gov=8'],
#   'words': ['اغتالوا',
#    'أبيّ',
#    'ابن',
#    'الست',
#    'سنوات',
#    'وهو',
#    'في',
#    'بيته',
#    'وعلى',
#    'سريره'],
#   'pos_tags': ['CD', 'CD', 'CD', 'CD', 'CD', 'CD', 'NN', 'CD', 'CD', 'CD']},
#  'اغتالوه من المستوطنة ذاتها القريبة\nمن بيتي': {'events': [<__main__.Event at 0x1a1d1c43c8>],
#   'penn_treebank': '(ROOT  (NP    (NP      (NP (NN اغتالوه))      (SBAR        (S          (VP (SYM من)            (NP (CD المستوطنة))))))    (NP      (NP        (QP (CD ذاتها) (CD القريبة)))      (NP (NN من) (CD بيتي)))))',
#   'triples': ['ROOT/dep=0/gov=-1',
#    'dep/dep=1/gov=2',
#    'acl:relcl/dep=2/gov=0',
#    'compound/dep=3/gov=4',
#    'dep/dep=4/gov=0',
#    'dep/dep=5/gov=4',
#    'nummod/dep=6/gov=5'],
#   'words': ['اغتالوه', 'من', 'المستوطنة', 'ذاتها', 'القريبة', 'من', 'بيتي'],
#   'pos_tags': ['NN', 'SYM', 'CD', 'CD', 'CD', 'NN', 'CD']},
#  'وا\nاغتيال أي فرد من أفراد عائلتي': {'events': [<__main__.Event at 0x1a18de12b0>],
#   'penn_treebank': '(ROOT  (FRAG    (X      (X (SYM وا))      (NP        (NP (CD اغتيال) (CD أي))        (NP (CD فرد) (NN من))))    (NP (CD أفراد) (CD عائلتي))))',
#   'triples': ['ROOT/dep=6/gov=-1',
#    'dep/dep=0/gov=2',
#    'nummod/dep=1/gov=2',
#    'dep/dep=2/gov=6',
#    'nummod/dep=3/gov=4',
#    'dep/dep=4/gov=2',
#    'nummod/dep=5/gov=6'],
#   'words': ['وا', 'اغتيال', 'أي', 'فرد', 'من', 'أفراد', 'عائلتي'],
#   'pos_tags': ['SYM', 'CD', 'CD', 'CD', 'NN', 'CD', 'CD']},
#  'انفصلنا': {'events': [<__main__.Event at 0x1a1d133438>],
#   'penn_treebank': '(ROOT  (NP (NN انفصلنا)))',
#   'triples': ['ROOT/dep=0/gov=-1'],
#   'words': ['انفصلنا'],
#   'pos_tags': ['NN']},
#  'وا في اغتياله': {'events': [<__main__.Event at 0x1a1bb76b38>],
#   'penn_treebank': '(ROOT  (FRAG    (NP (NN وا))    (NP (CD في) (CD اغتياله))))',
#   'triples': ['ROOT/dep=0/gov=-1', 'nummod/dep=1/gov=2', 'dep/dep=2/gov=0'],
#   'words': ['وا', 'في', 'اغتياله'],
#   'pos_tags': ['NN', 'CD', 'CD']},
#  'لاسرائيل اغتيال': {'events': [<__main__.Event at 0x1a1cad7a58>],
#   'penn_treebank': '(ROOT  (FRAG    (NP (CD لاسرائيل) (CD اغتيال))))',
#   'triples': ['ROOT/dep=1/gov=-1', 'nummod/dep=0/gov=1'],
#   'words': ['لاسرائيل', 'اغتيال'],
#   'pos_tags': ['CD', 'CD']},
#  'إغتال الجيش الإسرائيلي، ليلة أمس\nالأول (الخميس)، عدنان الغول، الذي أعتبر رئيساً للجناح العسكري لحركة حماس\nفي قطاع غزة': {'events': [<__main__.Event at 0x1a1d12e518>],
#   'penn_treebank': '(ROOT  (NP    (NP      (NP        (NP          (QP (SYM إغتال) (CD الجيش) (CD الإسرائيلي))          (NN ،))        (QP (CD ليلة) (CD أمس)))      (SBAR        (WHNP          (NP (NN الأول))          (PRN (-LRB- -LRB-)            (NP-TMP (CD الخميس))            (-RRB- -RRB-)))        (S          (VP (SYM ،)            (NP (CD عدنان) (CD الغول) (NN ،))))))    (NP      (NP        (NP          (QP (CD الذي) (CD أعتبر))          (NN رئيساً))        (QP (CD للجناح) (CD العسكري)))      (NP        (NP          (QP (CD لحركة) (CD حماس))          (NN في))        (QP (CD قطاع) (CD غزة))))))',
#   'triples': ['ROOT/dep=3/gov=-1',
#    'dep/dep=0/gov=2',
#    'compound/dep=1/gov=2',
#    'nummod/dep=2/gov=3',
#    'compound/dep=4/gov=5',
#    'nummod/dep=5/gov=3',
#    'nsubj/dep=6/gov=13',
#    'punct/dep=7/gov=8',
#    'dep/dep=8/gov=6',
#    'punct/dep=9/gov=8',
#    'dep/dep=10/gov=13',
#    'nummod/dep=11/gov=13',
#    'nummod/dep=12/gov=13',
#    'acl:relcl/dep=13/gov=3',
#    'compound/dep=14/gov=15',
#    'nummod/dep=15/gov=16',
#    'dep/dep=16/gov=3',
#    'compound/dep=17/gov=18',
#    'nummod/dep=18/gov=16',
#    'compound/dep=19/gov=20',
#    'nummod/dep=20/gov=21',
#    'dep/dep=21/gov=16',
#    'compound/dep=22/gov=23',
#    'nummod/dep=23/gov=21'],
#   'words': ['إغتال',
#    'الجيش',
#    'الإسرائيلي',
#    '،',
#    'ليلة',
#    'أمس',
#    'الأول',
#    '-LRB-',
#    'الخميس',
#    '-RRB-',
#    '،',
#    'عدنان',
#    'الغول',
#    '،',
#    'الذي',
#    'أعتبر',
#    'رئيساً',
#    'للجناح',
#    'العسكري',
#    'لحركة',
#    'حماس',
#    'في',
#    'قطاع',
#    'غزة'],
#   'pos_tags': ['SYM',
#    'CD',
#    'CD',
#    'NN',
#    'CD',
#    'CD',
#    'NN',
#    '-LRB-',
#    'CD',
#    '-RRB-',
#    'SYM',
#    'CD',
#    'CD',
#    'NN',
#    'CD',
#    'CD',
#    'NN',
#    'CD',
#    'CD',
#    'CD',
#    'CD',
#    'NN',
#    'CD',
#    'CD']},
#  'اتجهوا شرقاً نحو أسدود': {'events': [<__main__.Event at 0x1a1d12e588>],
#   'penn_treebank': '(ROOT  (FRAG    (NP (CD اتجهوا) (CD شرقاً))    (NP (CD نحو) (CD أسدود))))',
#   'triples': ['ROOT/dep=1/gov=-1',
#    'nummod/dep=0/gov=1',
#    'nummod/dep=2/gov=3',
#    'dep/dep=3/gov=1'],
#   'words': ['اتجهوا', 'شرقاً', 'نحو', 'أسدود'],
#   'pos_tags': ['CD', 'CD', 'CD', 'CD']},
#  'رئيس التحرير التنفيذي\nلجريدة العربي الناصرية التوجه عبد الحليم قنديل لاعتداء': {'events': [<__main__.Event at 0x1a1af06ba8>],
#   'penn_treebank': '(ROOT  (FRAG    (X      (X (SYM رئيس))      (NP        (NP (CD التحرير) (CD التنفيذي) (NN لجريدة))        (NP          (NP            (QP (CD العربي) (CD الناصرية)))          (NP (CD التوجه) (CD عبد) (NN الحليم)))))    (NP (CD قنديل) (CD لاعتداء))))',
#   'triples': ['ROOT/dep=10/gov=-1',
#    'dep/dep=0/gov=3',
#    'nummod/dep=1/gov=3',
#    'nummod/dep=2/gov=3',
#    'dep/dep=3/gov=10',
#    'compound/dep=4/gov=5',
#    'dep/dep=5/gov=3',
#    'nummod/dep=6/gov=8',
#    'nummod/dep=7/gov=8',
#    'dep/dep=8/gov=5',
#    'nummod/dep=9/gov=10'],
#   'words': ['رئيس',
#    'التحرير',
#    'التنفيذي',
#    'لجريدة',
#    'العربي',
#    'الناصرية',
#    'التوجه',
#    'عبد',
#    'الحليم',
#    'قنديل',
#    'لاعتداء'],
#   'pos_tags': ['SYM',
#    'CD',
#    'CD',
#    'NN',
#    'CD',
#    'CD',
#    'CD',
#    'CD',
#    'NN',
#    'CD',
#    'CD']},
#  'عودتي الى المنزل بعد\nالسحور في الساعة الثالثة صباحا تقريبا في الطريق المعتاد لبيتي في الهرم\n(جنوب القاهرة) وبينما كنت اقترب من منزلي فوجئت بسيارة مسرعة قادمة نحوي\nخرج منها اربعة رجال اجسامهم ضخمة جدا وحملوني وادخلوني داخل السيارة': {'events': [<__main__.Event at 0x1a1978e860>],
#   'penn_treebank': '(ROOT  (FRAG    (X      (X        (X          (NP            (NP (CD عودتي) (CD الى) (NN المنزل))            (NP              (NP                (QP (CD بعد) (CD السحور))                (NN في))              (NP                (QP (CD الساعة) (CD الثالثة))                (QP (CD صباحا) (CD تقريبا)))))          (NP (NN في) (CD الطريق))          (NP            (NP (CD المعتاد))            (NP              (NP (CD لبيتي) (NN في) (NN الهرم))              (PRN (-LRB- -LRB-)                (NP (CD جنوب) (NN القاهرة))                (-RRB- -RRB-))              (NP (CD وبينما) (CD كنت)))))        (NP          (NP (CD اقترب) (NN من))          (NP            (NP              (QP (CD منزلي) (CD فوجئت))              (NN بسيارة))            (NP              (QP (CD مسرعة) (CD قادمة))              (QP (CD نحوي) (CD خرج))))))      (NP        (NP (CD منها) (CD اربعة))        (NP          (NP (CD رجال) (CD اجسامهم))          (NP            (QP (CD ضخمة) (CD جدا))            (QP (CD وحملوني) (CD وادخلوني))))))    (NP (CD داخل) (CD السيارة))))',
#   'triples': ['ROOT/dep=40/gov=-1',
#    'nummod/dep=0/gov=2',
#    'nummod/dep=1/gov=2',
#    'dep/dep=2/gov=12',
#    'compound/dep=3/gov=4',
#    'nummod/dep=4/gov=5',
#    'dep/dep=5/gov=2',
#    'compound/dep=6/gov=7',
#    'nummod/dep=7/gov=9',
#    'compound/dep=8/gov=9',
#    'dep/dep=9/gov=5',
#    'dep/dep=10/gov=12',
#    'nummod/dep=11/gov=10',
#    'dep/dep=12/gov=23',
#    'nummod/dep=13/gov=15',
#    'compound/dep=14/gov=15',
#    'dep/dep=15/gov=12',
#    'punct/dep=16/gov=18',
#    'nummod/dep=17/gov=18',
#    'appos/dep=18/gov=15',
#    'punct/dep=19/gov=18',
#    'nummod/dep=20/gov=21',
#    'dep/dep=21/gov=15',
#    'nummod/dep=22/gov=23',
#    'dep/dep=23/gov=32',
#    'compound/dep=24/gov=25',
#    'nummod/dep=25/gov=26',
#    'dep/dep=26/gov=23',
#    'compound/dep=27/gov=28',
#    'nummod/dep=28/gov=30',
#    'compound/dep=29/gov=30',
#    'dep/dep=30/gov=26',
#    'nummod/dep=31/gov=32',
#    'dep/dep=32/gov=40',
#    'nummod/dep=33/gov=34',
#    'dep/dep=34/gov=32',
#    'compound/dep=35/gov=36',
#    'nummod/dep=36/gov=38',
#    'compound/dep=37/gov=38',
#    'dep/dep=38/gov=34',
#    'nummod/dep=39/gov=40'],
#   'words': ['عودتي',
#    'الى',
#    'المنزل',
#    'بعد',
#    'السحور',
#    'في',
#    'الساعة',
#    'الثالثة',
#    'صباحا',
#    'تقريبا',
#    'في',
#    'الطريق',
#    'المعتاد',
#    'لبيتي',
#    'في',
#    'الهرم',
#    '-LRB-',
#    'جنوب',
#    'القاهرة',
#    '-RRB-',
#    'وبينما',
#    'كنت',
#    'اقترب',
#    'من',
#    'منزلي',
#    'فوجئت',
#    'بسيارة',
#    'مسرعة',
#    'قادمة',
#    'نحوي',
#    'خرج',
#    'منها',
#    'اربعة',
#    'رجال',
#    'اجسامهم',
#    'ضخمة',
#    'جدا',
#    'وحملوني',
#    'وادخلوني',
#    'داخل',
#    'السيارة'],
#   'pos_tags': ['CD',
#    'CD',
#    'NN',
#    'CD',
#    'CD',
#    'NN',
#    'CD',
#    'CD',
#    'CD',
#    'CD',
#    'NN',
#    'CD',
#    'CD',
#    'CD',
#    'NN',
#    'NN',
#    '-LRB-',
#    'CD',
#    'NN',
#    '-RRB-',
#    'CD',
#    'CD',
#    'CD',
#    'NN',
#    'CD',
#    'CD',
#    'NN',
#    'CD',
#    'CD',
#    'CD',
#    'CD',
#    'CD',
#    'CD',
#    'CD',
#    'CD',
#    'CD',
#    'CD',
#    'CD',
#    'CD',
#    'CD',
#    'CD']},
#  'وا سكينين على رقبتي وانهالوا على ضربا\nوبعد ساعة تقريبا جردوني من كل ثيابي والقوا بي في منطقة صحراوية خارج\nالقاهرة': {'events': [<__main__.Event at 0x1a189f9ac8>],
#   'penn_treebank': '(ROOT  (FRAG    (X      (X        (X          (X (SYM وا))          (NP            (NP (CD سكينين) (CD على))            (NP              (NP                (QP (CD رقبتي) (CD وانهالوا))                (QP (CD على) (CD ضربا)))              (NP                (NP                  (QP (CD وبعد) (CD ساعة))                  (NN تقريبا))                (QP (CD جردوني) (CD من))))))        (NP (NN كل) (CD ثيابي)))      (NP        (NP (CD والقوا) (NN بي))        (NP          (NP            (QP (CD في) (CD منطقة)))          (NP (CD صحراوية)))))    (NP (CD خارج) (CD القاهرة))))',
#   'triples': ['ROOT/dep=20/gov=-1',
#    'dep/dep=0/gov=2',
#    'nummod/dep=1/gov=2',
#    'dep/dep=2/gov=12',
#    'compound/dep=3/gov=4',
#    'nummod/dep=4/gov=6',
#    'compound/dep=5/gov=6',
#    'dep/dep=6/gov=2',
#    'compound/dep=7/gov=8',
#    'nummod/dep=8/gov=9',
#    'dep/dep=9/gov=6',
#    'compound/dep=10/gov=11',
#    'nummod/dep=11/gov=9',
#    'dep/dep=12/gov=15',
#    'nummod/dep=13/gov=12',
#    'nummod/dep=14/gov=15',
#    'dep/dep=15/gov=20',
#    'compound/dep=16/gov=17',
#    'dep/dep=17/gov=15',
#    'dep/dep=18/gov=17',
#    'nummod/dep=19/gov=20'],
#   'words': ['وا',
#    'سكينين',
#    'على',
#    'رقبتي',
#    'وانهالوا',
#    'على',
#    'ضربا',
#    'وبعد',
#    'ساعة',
#    'تقريبا',
#    'جردوني',
#    'من',
#    'كل',
#    'ثيابي',
#    'والقوا',
#    'بي',
#    'في',
#    'منطقة',
#    'صحراوية',
#    'خارج',
#    'القاهرة'],
#   'pos_tags': ['SYM',
#    'CD',
#    'CD',
#    'CD',
#    'CD',
#    'CD',
#    'CD',
#    'CD',
#    'CD',
#    'NN',
#    'CD',
#    'CD',
#    'NN',
#    'CD',
#    'CD',
#    'NN',
#    'CD',
#    'CD',
#    'CD',
#    'CD',
#    'CD']},
#  'ذبحوا فى الفلوجه': {'events': [<__main__.Event at 0x1a19a6ff98>],
#   'penn_treebank': '(ROOT  (FRAG    (NP (CD ذبحوا))    (NP (CD فى) (CD الفلوجه))))',
#   'triples': ['ROOT/dep=0/gov=-1', 'nummod/dep=1/gov=2', 'dep/dep=2/gov=0'],
#   'words': ['ذبحوا', 'فى', 'الفلوجه'],
#   'pos_tags': ['CD', 'CD', 'CD']},
#  'ماتتوا فى الفلوجه': {'events': [<__main__.Event at 0x1a1a3d9780>],
#   'penn_treebank': '(ROOT  (NP    (NP (JJ ماتتوا) (NN فى))    (NP (CD الفلوجه))))',
#   'triples': ['ROOT/dep=1/gov=-1', 'amod/dep=0/gov=1', 'dep/dep=2/gov=1'],
#   'words': ['ماتتوا', 'فى', 'الفلوجه'],
#   'pos_tags': ['JJ', 'NN', 'CD']},
#  'العراقى الى بيموت': {'events': [<__main__.Event at 0x1a19a6f898>],
#   'penn_treebank': '(ROOT  (FRAG    (NP (CD العراقى))    (NP (CD الى) (CD بيموت))))',
#   'triples': ['ROOT/dep=0/gov=-1', 'nummod/dep=1/gov=2', 'dep/dep=2/gov=0'],
#   'words': ['العراقى', 'الى', 'بيموت'],
#   'pos_tags': ['CD', 'CD', 'CD']},
#  'قتلوا بسبب العربات المفخخه التى\nيقودها عرب من خارج العراق و يتحصنون فى الفلوجه': {'events': [<__main__.Event at 0x1a1901a4a8>],
#   'penn_treebank': '(ROOT  (NP    (NP      (NP        (QP (SYM قتلوا) (CD بسبب) (CD العربات))        (QP (CD المفخخه) (CD التى)))      (NP        (QP (CD يقودها) (CD عرب))        (NN من)))    (NP      (NP        (NP (CD خارج) (CD العراق))        (SBAR          (S            (VP (SYM و)              (NP (CD يتحصنون) (CD فى))))))      (NP (CD الفلوجه)))))',
#   'triples': ['ROOT/dep=4/gov=-1',
#    'dep/dep=0/gov=2',
#    'compound/dep=1/gov=2',
#    'nummod/dep=2/gov=4',
#    'compound/dep=3/gov=4',
#    'compound/dep=5/gov=6',
#    'nummod/dep=6/gov=7',
#    'dep/dep=7/gov=4',
#    'nummod/dep=8/gov=9',
#    'dep/dep=9/gov=4',
#    'dep/dep=10/gov=12',
#    'nummod/dep=11/gov=12',
#    'acl:relcl/dep=12/gov=9',
#    'dep/dep=13/gov=9'],
#   'words': ['قتلوا',
#    'بسبب',
#    'العربات',
#    'المفخخه',
#    'التى',
#    'يقودها',
#    'عرب',
#    'من',
#    'خارج',
#    'العراق',
#    'و',
#    'يتحصنون',
#    'فى',
#    'الفلوجه'],
#   'pos_tags': ['SYM',
#    'CD',
#    'CD',
#    'CD',
#    'CD',
#    'CD',
#    'CD',
#    'NN',
#    'CD',
#    'CD',
#    'SYM',
#    'CD',
#    'CD',
#    'CD']},
#  'برحيل عرفات': {'events': [<__main__.Event at 0x1a1a0163c8>],
#   'penn_treebank': '(ROOT  (FRAG    (NP (CD برحيل) (CD عرفات))))',
#   'triples': ['ROOT/dep=1/gov=-1', 'nummod/dep=0/gov=1'],
#   'words': ['برحيل', 'عرفات'],
#   'pos_tags': ['CD', 'CD']},
#  'مصر لتنشيط السلام على المسار السوري و الفلسطيني\nبزيارة وزير الخارجية المصري لاسرائيل': {'events': [<__main__.Event at 0x1a1be985f8>],
#   'penn_treebank': '(ROOT  (NP    (NP      (NP        (QP (CD مصر) (CD لتنشيط)))      (NP (NN السلام) (CD على)))    (NP      (NP        (NP (CD المسار) (CD السوري))        (SBAR          (S            (VP (SYM و)              (NP (CD الفلسطيني) (CD بزيارة))))))      (NP        (NP          (QP (CD وزير) (CD الخارجية)))        (NP (NN المصري) (CD لاسرائيل))))))',
#   'triples': ['ROOT/dep=1/gov=-1',
#    'compound/dep=0/gov=1',
#    'dep/dep=2/gov=1',
#    'nummod/dep=3/gov=2',
#    'nummod/dep=4/gov=5',
#    'dep/dep=5/gov=1',
#    'dep/dep=6/gov=8',
#    'nummod/dep=7/gov=8',
#    'acl:relcl/dep=8/gov=5',
#    'compound/dep=9/gov=10',
#    'dep/dep=10/gov=5',
#    'dep/dep=11/gov=10',
#    'nummod/dep=12/gov=11'],
#   'words': ['مصر',
#    'لتنشيط',
#    'السلام',
#    'على',
#    'المسار',
#    'السوري',
#    'و',
#    'الفلسطيني',
#    'بزيارة',
#    'وزير',
#    'الخارجية',
#    'المصري',
#    'لاسرائيل'],
#   'pos_tags': ['CD',
#    'CD',
#    'NN',
#    'CD',
#    'CD',
#    'CD',
#    'SYM',
#    'CD',
#    'CD',
#    'CD',
#    'CD',
#    'NN',
#    'CD']},
#  'الحركة المصرية من أجل التغيير مظاهرة من نوع جديد اليوم': {'events': [<__main__.Event at 0x1a19f34e48>],
#   'penn_treebank': '(ROOT  (NP    (NP      (NP (NN الحركة) (CD المصرية) (NN من))      (NP        (QP (CD أجل) (CD التغيير))))    (NP      (NP (CD مظاهرة) (NN من))      (NP        (QP (CD نوع) (CD جديد))        (CD اليوم)))))',
#   'triples': ['ROOT/dep=2/gov=-1',
#    'compound/dep=0/gov=2',
#    'nummod/dep=1/gov=2',
#    'compound/dep=3/gov=4',
#    'dep/dep=4/gov=2',
#    'nummod/dep=5/gov=6',
#    'dep/dep=6/gov=2',
#    'compound/dep=7/gov=8',
#    'nummod/dep=8/gov=9',
#    'dep/dep=9/gov=6'],
#   'words': ['الحركة',
#    'المصرية',
#    'من',
#    'أجل',
#    'التغيير',
#    'مظاهرة',
#    'من',
#    'نوع',
#    'جديد',
#    'اليوم'],
#   'pos_tags': ['NN', 'CD', 'NN', 'CD', 'CD', 'CD', 'NN', 'CD', 'CD', 'CD']},
#  'يتظاهرون في القاهرة': {'events': [<__main__.Event at 0x1a18dd7f60>],
#   'penn_treebank': '(ROOT  (FRAG    (NP (CD يتظاهرون))    (NP (CD في) (CD القاهرة))))',
#   'triples': ['ROOT/dep=0/gov=-1', 'nummod/dep=1/gov=2', 'dep/dep=2/gov=0'],
#   'words': ['يتظاهرون', 'في', 'القاهرة'],
#   'pos_tags': ['CD', 'CD', 'CD']},
#  'المظاهرة': {'events': [<__main__.Event at 0x1a18dd73c8>],
#   'penn_treebank': '(ROOT  (NP (NN المظاهرة)))',
#   'triples': ['ROOT/dep=0/gov=-1'],
#   'words': ['المظاهرة'],
#   'pos_tags': ['NN']},
#  'أروح المظاهرة الأقي انكم قدمتوا المعاد نص\nساعة بحالها ومنعين الناس من الهتاف طب قاعدين ليه متقوموا تروحوا ويعدين\nايه المظاهرة دية اللي مقعدتش الأنص ساعة': {'events': [<__main__.Event at 0x1a1d1af630>],
#   'penn_treebank': '(ROOT  (FRAG    (X      (X        (X          (X            (X (SYM أروح))            (NP              (NP (CD المظاهرة) (CD الأقي))              (NP                (NP                  (QP (CD انكم) (CD قدمتوا)))                (NP (CD المعاد) (NN نص)))))          (NP            (NP (CD ساعة))            (NP              (NP                (QP (CD بحالها) (CD ومنعين)))              (NP (CD الناس) (NN من)))))        (NP          (NP (CD الهتاف) (NN طب))          (NP            (NP              (QP (CD قاعدين) (CD ليه)))            (NP (CD متقوموا) (NN تروحوا)))))      (NP        (NP (CD ويعدين) (CD ايه))        (NP          (NP            (QP (CD المظاهرة) (CD دية)))          (NP (CD اللي) (NN مقعدتش)))))    (NP (CD الأنص) (CD ساعة))))',
#   'triples': ['ROOT/dep=25/gov=-1',
#    'dep/dep=0/gov=2',
#    'nummod/dep=1/gov=2',
#    'dep/dep=2/gov=7',
#    'compound/dep=3/gov=4',
#    'dep/dep=4/gov=2',
#    'nummod/dep=5/gov=6',
#    'dep/dep=6/gov=4',
#    'dep/dep=7/gov=13',
#    'compound/dep=8/gov=9',
#    'dep/dep=9/gov=7',
#    'nummod/dep=10/gov=11',
#    'dep/dep=11/gov=9',
#    'nummod/dep=12/gov=13',
#    'dep/dep=13/gov=19',
#    'compound/dep=14/gov=15',
#    'dep/dep=15/gov=13',
#    'nummod/dep=16/gov=17',
#    'dep/dep=17/gov=15',
#    'nummod/dep=18/gov=19',
#    'dep/dep=19/gov=25',
#    'compound/dep=20/gov=21',
#    'dep/dep=21/gov=19',
#    'nummod/dep=22/gov=23',
#    'dep/dep=23/gov=21',
#    'nummod/dep=24/gov=25'],
#   'words': ['أروح',
#    'المظاهرة',
#    'الأقي',
#    'انكم',
#    'قدمتوا',
#    'المعاد',
#    'نص',
#    'ساعة',
#    'بحالها',
#    'ومنعين',
#    'الناس',
#    'من',
#    'الهتاف',
#    'طب',
#    'قاعدين',
#    'ليه',
#    'متقوموا',
#    'تروحوا',
#    'ويعدين',
#    'ايه',
#    'المظاهرة',
#    'دية',
#    'اللي',
#    'مقعدتش',
#    'الأنص',
#    'ساعة'],
#   'pos_tags': ['SYM',
#    'CD',
#    'CD',
#    'CD',
#    'CD',
#    'CD',
#    'NN',
#    'CD',
#    'CD',
#    'CD',
#    'CD',
#    'NN',
#    'CD',
#    'NN',
#    'CD',
#    'CD',
#    'CD',
#    'NN',
#    'CD',
#    'CD',
#    'CD',
#    'CD',
#    'CD',
#    'NN',
#    'CD',
#    'CD']},
#  'ترشح نفسها للرئاسة\nالمصرية': {'events': [<__main__.Event at 0x1a19f34390>],
#   'penn_treebank': '(ROOT  (FRAG    (X (SYM ترشح))    (SYM نفسها)    (NP (CD للرئاسة) (CD المصرية))))',
#   'triples': ['ROOT/dep=3/gov=-1',
#    'dep/dep=0/gov=3',
#    'dep/dep=1/gov=3',
#    'nummod/dep=2/gov=3'],
#   'words': ['ترشح', 'نفسها', 'للرئاسة', 'المصرية'],
#   'pos_tags': ['SYM', 'SYM', 'CD', 'CD']},
#  'أحد نائبين قبض عليهما بعد مظاهرات': {'events': [<__main__.Event at 0x1a19f34ba8>],
#   'penn_treebank': '(ROOT  (NP    (NP (CD أحد) (CD نائبين))    (NP      (NP (CD قبض) (NN عليهما))      (NP        (QP (CD بعد) (CD مظاهرات))))))',
#   'triples': ['ROOT/dep=1/gov=-1',
#    'nummod/dep=0/gov=1',
#    'nummod/dep=2/gov=3',
#    'dep/dep=3/gov=1',
#    'compound/dep=4/gov=5',
#    'dep/dep=5/gov=3'],
#   'words': ['أحد', 'نائبين', 'قبض', 'عليهما', 'بعد', 'مظاهرات'],
#   'pos_tags': ['CD', 'CD', 'CD', 'NN', 'CD', 'CD']},
#  'الرئيس قال في احنماع': {'events': [<__main__.Event at 0x1a19f347f0>],
#   'penn_treebank': '(ROOT  (NP    (NP (CD الرئيس))    (NP (CD قال) (NN في))    (NP (CD احنماع))))',
#   'triples': ['ROOT/dep=0/gov=-1',
#    'nummod/dep=1/gov=2',
#    'dep/dep=2/gov=0',
#    'dep/dep=3/gov=0'],
#   'words': ['الرئيس', 'قال', 'في', 'احنماع'],
#   'pos_tags': ['CD', 'CD', 'NN', 'CD']},
#  'أكسب الانتخابات': {'events': [<__main__.Event at 0x1a1d1afa20>],
#   'penn_treebank': '(ROOT  (NP (NN أكسب) (CD الانتخابات)))',
#   'triples': ['ROOT/dep=0/gov=-1', 'nummod/dep=1/gov=0'],
#   'words': ['أكسب', 'الانتخابات'],
#   'pos_tags': ['NN', 'CD']},
#  'اجتماع لوزراء الخارجية العرب': {'events': [<__main__.Event at 0x1a199b8160>],
#   'penn_treebank': '(ROOT  (NP    (NP      (NP (NN اجتماع))      (SBAR        (S          (VP (SYM لوزراء)            (NP (CD الخارجية))))))    (NP (CD العرب))))',
#   'triples': ['ROOT/dep=0/gov=-1',
#    'dep/dep=1/gov=2',
#    'acl:relcl/dep=2/gov=0',
#    'dep/dep=3/gov=0'],
#   'words': ['اجتماع', 'لوزراء', 'الخارجية', 'العرب'],
#   'pos_tags': ['NN', 'SYM', 'CD', 'CD']},
#  'في يوليو 1990 التقى الرئيس العراقي صدام\nحسين بالرئيس المصري مبارك في بغداد': {'events': [<__main__.Event at 0x1a1cedf048>],
#   'penn_treebank': '(ROOT  (NP    (NP      (NP (NN في))      (SBAR        (S          (VP (SYM يوليو)            (NP (CD 1990) (CD التقى) (NN الرئيس))))))    (NP      (NP        (NP          (QP (CD العراقي) (CD صدام))          (QP (CD حسين) (CD بالرئيس)))        (QP (CD المصري) (CD مبارك)))      (NP (NN في) (CD بغداد)))))',
#   'triples': ['ROOT/dep=0/gov=-1',
#    'dep/dep=1/gov=4',
#    'nummod/dep=2/gov=4',
#    'nummod/dep=3/gov=4',
#    'acl:relcl/dep=4/gov=0',
#    'compound/dep=5/gov=6',
#    'nummod/dep=6/gov=8',
#    'compound/dep=7/gov=8',
#    'dep/dep=8/gov=0',
#    'compound/dep=9/gov=10',
#    'nummod/dep=10/gov=8',
#    'dep/dep=11/gov=8',
#    'nummod/dep=12/gov=11'],
#   'words': ['في',
#    'يوليو',
#    '1990',
#    'التقى',
#    'الرئيس',
#    'العراقي',
#    'صدام',
#    'حسين',
#    'بالرئيس',
#    'المصري',
#    'مبارك',
#    'في',
#    'بغداد'],
#   'pos_tags': ['NN',
#    'SYM',
#    'CD',
#    'CD',
#    'NN',
#    'CD',
#    'CD',
#    'CD',
#    'CD',
#    'CD',
#    'CD',
#    'NN',
#    'CD']},
#  'جدة في آخر يوليو التقى عزة ابراهيم مع الشيخ سعد الصباح': {'events': [<__main__.Event at 0x1a1cedf240>],
#   'penn_treebank': '(ROOT  (NP    (NP      (NP (CD جدة) (CD في))      (NP        (QP (CD آخر) (CD يوليو))        (QP (CD التقى) (CD عزة))))    (NP      (NP (CD ابراهيم) (NN مع))      (NP        (QP (CD الشيخ) (CD سعد))        (NN الصباح)))))',
#   'triples': ['ROOT/dep=1/gov=-1',
#    'nummod/dep=0/gov=1',
#    'compound/dep=2/gov=3',
#    'nummod/dep=3/gov=5',
#    'compound/dep=4/gov=5',
#    'dep/dep=5/gov=1',
#    'nummod/dep=6/gov=7',
#    'dep/dep=7/gov=1',
#    'compound/dep=8/gov=9',
#    'nummod/dep=9/gov=10',
#    'dep/dep=10/gov=7'],
#   'words': ['جدة',
#    'في',
#    'آخر',
#    'يوليو',
#    'التقى',
#    'عزة',
#    'ابراهيم',
#    'مع',
#    'الشيخ',
#    'سعد',
#    'الصباح'],
#   'pos_tags': ['CD',
#    'CD',
#    'CD',
#    'CD',
#    'CD',
#    'CD',
#    'CD',
#    'NN',
#    'CD',
#    'CD',
#    'NN']},
#  'أرسل الأدميرال بيل أوينز الى تشيني': {'events': [<__main__.Event at 0x1a1a1a8b70>],
#   'penn_treebank': '(ROOT  (NP    (NP      (NP        (QP (SYM أرسل) (CD الأدميرال) (CD بيل)))      (NP (CD أوينز)))    (NP (CD الى) (CD تشيني))))',
#   'triples': ['ROOT/dep=2/gov=-1',
#    'dep/dep=0/gov=2',
#    'compound/dep=1/gov=2',
#    'dep/dep=3/gov=2',
#    'nummod/dep=4/gov=5',
#    'dep/dep=5/gov=2'],
#   'words': ['أرسل', 'الأدميرال', 'بيل', 'أوينز', 'الى', 'تشيني'],
#   'pos_tags': ['SYM', 'CD', 'CD', 'CD', 'CD', 'CD']},
#  'لتنتقل الى\nالسعودية': {'events': [<__main__.Event at 0x1a1a307048>],
#   'penn_treebank': '(ROOT  (FRAG    (NP (NN لتنتقل))    (NP (CD الى) (CD السعودية))))',
#   'triples': ['ROOT/dep=0/gov=-1', 'nummod/dep=1/gov=2', 'dep/dep=2/gov=0'],
#   'words': ['لتنتقل', 'الى', 'السعودية'],
#   'pos_tags': ['NN', 'CD', 'CD']},
#  'ترشيح نفسه لمنصب رئاسة\nالجمهورية': {'events': [<__main__.Event at 0x1a1ae5f470>],
#   'penn_treebank': '(ROOT  (FRAG    (X      (X        (X (SYM ترشيح))        (NP (CD نفسه)))      (NP (CD لمنصب)))    (NP (CD رئاسة) (CD الجمهورية))))',
#   'triples': ['ROOT/dep=4/gov=-1',
#    'dep/dep=0/gov=1',
#    'dep/dep=1/gov=2',
#    'dep/dep=2/gov=4',
#    'nummod/dep=3/gov=4'],
#   'words': ['ترشيح', 'نفسه', 'لمنصب', 'رئاسة', 'الجمهورية'],
#   'pos_tags': ['SYM', 'CD', 'CD', 'CD', 'CD']},
#  'ترشيح أنفسهم': {'events': [<__main__.Event at 0x1a1ae5f908>],
#   'penn_treebank': '(ROOT  (FRAG    (NP (CD ترشيح) (CD أنفسهم))))',
#   'triples': ['ROOT/dep=1/gov=-1', 'nummod/dep=0/gov=1'],
#   'words': ['ترشيح', 'أنفسهم'],
#   'pos_tags': ['CD', 'CD']},
#  'سيرشح': {'events': [<__main__.Event at 0x1a1baa0978>],
#   'penn_treebank': '(ROOT  (X (SYM سيرشح)))',
#   'triples': ['ROOT/dep=0/gov=-1'],
#   'words': ['سيرشح'],
#   'pos_tags': ['SYM']},
#  'تقدم المهندس المصري يسري\nالسيد متولي والذي لا ينتمي الى أي حزب سياسي ويعمل باحدى شركات المنسوجات\nبمدينة الاسكندرية بطلب ترشيحه لمنصب رئيس الجمهورية الى البرلمان المصري': {'events': [<__main__.Event at 0x1a1d1c4e80>],
#   'penn_treebank': '(ROOT  (FRAG    (X      (X        (X          (X            (X              (X (SYM تقدم))              (NP                (NP (CD المهندس) (CD المصري))                (NP                  (NP                    (QP (CD يسري) (CD السيد)))                  (NP (CD متولي) (CD والذي)))))            (NP (NN لا) (CD ينتمي)))          (NP            (NP (CD الى) (NN أي))            (NP              (NP (CD حزب) (CD سياسي))              (NP                (QP (CD ويعمل) (CD باحدى))                (QP (CD شركات) (CD المنسوجات))))))        (NP (NN بمدينة) (CD الاسكندرية)))      (NP        (NP (CD بطلب) (NN ترشيحه))        (NP          (NP            (QP (CD لمنصب) (CD رئيس)))          (NP (CD الجمهورية) (CD الى)))))    (NP (CD البرلمان) (NN المصري))))',
#   'triples': ['ROOT/dep=26/gov=-1',
#    'dep/dep=0/gov=2',
#    'nummod/dep=1/gov=2',
#    'dep/dep=2/gov=7',
#    'compound/dep=3/gov=4',
#    'dep/dep=4/gov=2',
#    'nummod/dep=5/gov=6',
#    'dep/dep=6/gov=4',
#    'dep/dep=7/gov=10',
#    'nummod/dep=8/gov=7',
#    'nummod/dep=9/gov=10',
#    'dep/dep=10/gov=17',
#    'nummod/dep=11/gov=12',
#    'dep/dep=12/gov=10',
#    'compound/dep=13/gov=14',
#    'nummod/dep=14/gov=16',
#    'compound/dep=15/gov=16',
#    'dep/dep=16/gov=12',
#    'dep/dep=17/gov=20',
#    'nummod/dep=18/gov=17',
#    'nummod/dep=19/gov=20',
#    'dep/dep=20/gov=26',
#    'compound/dep=21/gov=22',
#    'dep/dep=22/gov=20',
#    'nummod/dep=23/gov=24',
#    'dep/dep=24/gov=22',
#    'nummod/dep=25/gov=26'],
#   'words': ['تقدم',
#    'المهندس',
#    'المصري',
#    'يسري',
#    'السيد',
#    'متولي',
#    'والذي',
#    'لا',
#    'ينتمي',
#    'الى',
#    'أي',
#    'حزب',
#    'سياسي',
#    'ويعمل',
#    'باحدى',
#    'شركات',
#    'المنسوجات',
#    'بمدينة',
#    'الاسكندرية',
#    'بطلب',
#    'ترشيحه',
#    'لمنصب',
#    'رئيس',
#    'الجمهورية',
#    'الى',
#    'البرلمان',
#    'المصري'],
#   'pos_tags': ['SYM',
#    'CD',
#    'CD',
#    'CD',
#    'CD',
#    'CD',
#    'CD',
#    'NN',
#    'CD',
#    'CD',
#    'NN',
#    'CD',
#    'CD',
#    'CD',
#    'CD',
#    'CD',
#    'CD',
#    'NN',
#    'CD',
#    'CD',
#    'NN',
#    'CD',
#    'CD',
#    'CD',
#    'CD',
#    'CD',
#    'NN']},
#  'الرئيس مبارك فاز': {'events': [<__main__.Event at 0x1a1946a9e8>],
#   'penn_treebank': '(ROOT  (PP (IN الرئيس)    (NP (CD مبارك) (CD فاز))))',
#   'triples': ['ROOT/dep=2/gov=-1', 'case/dep=0/gov=2', 'nummod/dep=1/gov=2'],
#   'words': ['الرئيس', 'مبارك', 'فاز'],
#   'pos_tags': ['IN', 'CD', 'CD']},
#  'سيرشحه\nفي مايو': {'events': [<__main__.Event at 0x1a18dd8748>],
#   'penn_treebank': '(ROOT  (NP    (NP (JJ سيرشحه) (NN في))    (NP (CD مايو))))',
#   'triples': ['ROOT/dep=1/gov=-1', 'amod/dep=0/gov=1', 'dep/dep=2/gov=1'],
#   'words': ['سيرشحه', 'في', 'مايو'],
#   'pos_tags': ['JJ', 'NN', 'CD']},
#  'الرئيس المصري معتقل بأنها اعتقلت': {'events': [<__main__.Event at 0x1a1946a588>],
#   'penn_treebank': '(ROOT  (NP    (NP (NN الرئيس))    (NP      (NP        (QP (CD المصري) (CD معتقل)))      (NP (CD بأنها) (NN اعتقلت)))))',
#   'triples': ['ROOT/dep=0/gov=-1',
#    'compound/dep=1/gov=2',
#    'dep/dep=2/gov=0',
#    'nummod/dep=3/gov=4',
#    'dep/dep=4/gov=2'],
#   'words': ['الرئيس', 'المصري', 'معتقل', 'بأنها', 'اعتقلت'],
#   'pos_tags': ['NN', 'CD', 'CD', 'CD', 'NN']},
#  'اعتقالها في أحداث\nسبتمبر 1981 على يد السادات': {'events': [<__main__.Event at 0x1a1a1a8630>],
#   'penn_treebank': '(ROOT  (NP    (NP      (NP        (QP (CD اعتقالها) (CD في))        (CD أحداث))      (ADJP (JJ سبتمبر)        (NP-TMP (CD 1981))))    (NP      (NP (CD على) (NN يد))      (NP (CD السادات)))))',
#   'triples': ['ROOT/dep=2/gov=-1',
#    'compound/dep=0/gov=1',
#    'nummod/dep=1/gov=2',
#    'amod/dep=3/gov=2',
#    'obl:tmod/dep=4/gov=3',
#    'nummod/dep=5/gov=6',
#    'dep/dep=6/gov=2',
#    'dep/dep=7/gov=6'],
#   'words': ['اعتقالها',
#    'في',
#    'أحداث',
#    'سبتمبر',
#    '1981',
#    'على',
#    'يد',
#    'السادات'],
#   'pos_tags': ['CD', 'CD', 'CD', 'JJ', 'CD', 'CD', 'NN', 'CD']},
#  'اغتيال السادات': {'events': [<__main__.Event at 0x1a1900edd8>],
#   'penn_treebank': '(ROOT  (NP (NN اغتيال) (CD السادات)))',
#   'triples': ['ROOT/dep=0/gov=-1', 'nummod/dep=1/gov=0'],
#   'words': ['اغتيال', 'السادات'],
#   'pos_tags': ['NN', 'CD']},
#  'الافراج عن المعتقلين': {'events': [<__main__.Event at 0x1a19d13f28>],
#   'penn_treebank': '(ROOT  (FRAG    (NP (CD الافراج))    (NP (CD عن) (CD المعتقلين))))',
#   'triples': ['ROOT/dep=0/gov=-1', 'nummod/dep=1/gov=2', 'dep/dep=2/gov=0'],
#   'words': ['الافراج', 'عن', 'المعتقلين'],
#   'pos_tags': ['CD', 'CD', 'CD']},
#  'اقتيدوا من المعتقل الى مقر الرئيس': {'events': [<__main__.Event at 0x1a19235278>],
# ...
#   'triples': ['ROOT/dep=18/gov=-1',
#    'nummod/dep=0/gov=2',
#    'nummod/dep=1/gov=2',
#    'dep/dep=2/gov=11',
#    'nummod/dep=3/gov=4',
#    'dep/dep=4/gov=2',
#    'compound/dep=5/gov=6',
#    'dep/dep=6/gov=4',
#    'dep/dep=7/gov=11',
#    'nummod/dep=8/gov=7',
#    'nummod/dep=9/gov=11',
#    'nummod/dep=10/gov=11',
#    'dep/dep=11/gov=15',
#    'compound/dep=12/gov=13',
#    'dep/dep=13/gov=11',
#    'dep/dep=14/gov=13',
#    'dep/dep=15/gov=18',
#    'nummod/dep=16/gov=15',
#    'nummod/dep=17/gov=18'],
#   'words': ['الجمعة',
#    'عددا',
#    'من',
#    'الفلسطينيين',
#    'من',
#    'الوصول',
#    'الى',
#    'الحدود',
#    'بين',
#    'البلدين',
#    'للتظاهر',
#    '،',
#    'اثر',
#    'تهديدات',
#    'اسرائيلية',
#    'باطلاق',
#    'النار',
#    'على',
#    'المتظاهرين'],
#   'pos_tags': ['CD',
#    'CD',
#    'NN',
#    'CD',
#    'NN',
#    'CD',
#    'CD',
#    'NN',
#    'CD',
#    'CD',
#    'CD',
#    'NN',
#    'CD',
#    'CD',
#    'CD',
#    'NN',
#    'CD',
#    'CD',
#    'NN']},
#  'انتشرت في التاسع من آب/اغسطس في المنطقة التي كانت\nتحتلها اسرائيل': {'events': [<__main__.Event at 0x1a1be92d30>],
#   'penn_treebank': '(ROOT  (NP    (NP      (NP (NN انتشرت))      (SBAR        (S          (VP (SYM في)            (NP (CD التاسع) (CD من))))))    (NP      (NP (CD آب/اغسطس) (NN في))      (NP        (NP          (NP            (QP (CD المنطقة) (CD التي)))          (NP (CD كانت) (NN تحتلها)))        (NP (CD اسرائيل))))))',
#   'triples': ['ROOT/dep=0/gov=-1',
#    'dep/dep=1/gov=3',
#    'nummod/dep=2/gov=3',
#    'acl:relcl/dep=3/gov=0',
#    'nummod/dep=4/gov=5',
#    'dep/dep=5/gov=0',
#    'compound/dep=6/gov=7',
#    'dep/dep=7/gov=5',
#    'nummod/dep=8/gov=9',
#    'dep/dep=9/gov=7',
#    'dep/dep=10/gov=7'],
#   'words': ['انتشرت',
#    'في',
#    'التاسع',
#    'من',
#    'آب/اغسطس',
#    'في',
#    'المنطقة',
#    'التي',
#    'كانت',
#    'تحتلها',
#    'اسرائيل'],
#   'pos_tags': ['NN',
#    'SYM',
#    'CD',
#    'CD',
#    'CD',
#    'NN',
#    'CD',
#    'CD',
#    'CD',
#    'NN',
#    'CD']},
#  'اللاجئين الفلسطينيين من التظاهر\nعلى الحدود': {'events': [<__main__.Event at 0x1a1ec625f8>],
#   'penn_treebank': '(ROOT  (FRAG    (NP (CD اللاجئين) (CD الفلسطينيين))    (NP      (NP (NN من))      (NP        (QP (CD التظاهر) (CD على))        (NN الحدود)))))',
#   'triples': ['ROOT/dep=1/gov=-1',
#    'nummod/dep=0/gov=1',
#    'dep/dep=2/gov=1',
#    'compound/dep=3/gov=4',
#    'nummod/dep=4/gov=5',
#    'dep/dep=5/gov=2'],
#   'words': ['اللاجئين', 'الفلسطينيين', 'من', 'التظاهر', 'على', 'الحدود'],
#   'pos_tags': ['CD', 'CD', 'NN', 'CD', 'CD', 'NN']},
#  'الجمعة عددا من الفلسطينيين من الوصول الى\nالحدود بين البلدين': {'events': [<__main__.Event at 0x1a1ec62470>],
#   'penn_treebank': '(ROOT  (NP    (NP (CD الجمعة) (CD عددا) (NN من))    (NP      (NP (CD الفلسطينيين) (NN من))      (NP        (QP (CD الوصول) (CD الى))        (NN الحدود)))    (NP (CD بين) (CD البلدين))))',
#   'triples': ['ROOT/dep=2/gov=-1',
#    'nummod/dep=0/gov=2',
#    'nummod/dep=1/gov=2',
#    'nummod/dep=3/gov=4',
#    'dep/dep=4/gov=2',
#    'compound/dep=5/gov=6',
#    'nummod/dep=6/gov=7',
#    'dep/dep=7/gov=4',
#    'nummod/dep=8/gov=9',
#    'dep/dep=9/gov=2'],
#   'words': ['الجمعة',
#    'عددا',
#    'من',
#    'الفلسطينيين',
#    'من',
#    'الوصول',
#    'الى',
#    'الحدود',
#    'بين',
#    'البلدين'],
#   'pos_tags': ['CD', 'CD', 'NN', 'CD', 'NN', 'CD', 'CD', 'NN', 'CD', 'CD']},
#  'اقعلت': {'events': [<__main__.Event at 0x1a1dfd35c0>],
#   'penn_treebank': '(ROOT  (X (SYM اقعلت)))',
#   'triples': ['ROOT/dep=0/gov=-1'],
#   'words': ['اقعلت'],
#   'pos_tags': ['SYM']},
#  'يسافران معا لقضاء اجازتهما فى\nبريطانيا وفرنسا ومصر والمغرب': {'events': [<__main__.Event at 0x1a1cc53ef0>],
#   'penn_treebank': '(ROOT  (FRAG    (NP (CD يسافران) (CD معا))    (NP      (NP (CD لقضاء) (CD اجازتهما) (NN فى))      (NP        (QP (CD بريطانيا) (CD وفرنسا))        (QP (CD ومصر) (CD والمغرب))))))',
#   'triples': ['ROOT/dep=1/gov=-1',
#    'nummod/dep=0/gov=1',
#    'nummod/dep=2/gov=4',
#    'nummod/dep=3/gov=4',
#    'dep/dep=4/gov=1',
#    'compound/dep=5/gov=6',
#    'nummod/dep=6/gov=8',
#    'compound/dep=7/gov=8',
#    'dep/dep=8/gov=4'],
#   'words': ['يسافران',
#    'معا',
#    'لقضاء',
#    'اجازتهما',
#    'فى',
#    'بريطانيا',
#    'وفرنسا',
#    'ومصر',
#    'والمغرب'],
#   'pos_tags': ['CD', 'CD', 'CD', 'CD', 'NN', 'CD', 'CD', 'CD', 'CD']},
#  'عادوا\nالى الرياض مساء امس الاحد من بغداد': {'events': [<__main__.Event at 0x1a1dfd35f8>],
#   'penn_treebank': '(ROOT  (NP    (NP      (NP        (QP (SYM عادوا) (CD الى) (CD الرياض)))      (NP (CD مساء)))    (NP      (NP        (QP (CD امس) (CD الاحد)))      (NP (NN من) (CD بغداد)))))',
#   'triples': ['ROOT/dep=2/gov=-1',
#    'dep/dep=0/gov=2',
#    'compound/dep=1/gov=2',
#    'dep/dep=3/gov=2',
#    'compound/dep=4/gov=5',
#    'dep/dep=5/gov=2',
#    'dep/dep=6/gov=5',
#    'nummod/dep=7/gov=6'],
#   'words': ['عادوا', 'الى', 'الرياض', 'مساء', 'امس', 'الاحد', 'من', 'بغداد'],
#   'pos_tags': ['SYM', 'CD', 'CD', 'CD', 'CD', 'CD', 'NN', 'CD']},
#  'الطائرة السعودية التى خطفت السبت فى الاجواء المصرية عادوا\nالى الرياض مساء امس الاحد من بغداد ثم غادروا فجر اليوم الاثنين الى\nلندن': {'events': [<__main__.Event at 0x1a1e04bc50>],
#   'penn_treebank': '(ROOT  (FRAG    (X      (NP        (NP (CD الطائرة) (CD السعودية))        (NP          (NP            (NP              (QP (CD التى) (CD خطفت)))            (NP (CD السبت) (NN فى)))          (NP            (QP (CD الاجواء) (CD المصرية))            (QP (CD عادوا) (CD الى)))))      (NP (NN الرياض) (CD مساء))      (NP        (NP (CD امس) (CD الاحد) (NN من))        (NP          (NP (CD بغداد) (NN ثم))          (NP            (QP (CD غادروا) (CD فجر))            (QP (CD اليوم) (CD الاثنين))))))    (NP (CD الى) (CD لندن))))',
#   'triples': ['ROOT/dep=22/gov=-1',
#    'nummod/dep=0/gov=1',
#    'dep/dep=1/gov=14',
#    'compound/dep=2/gov=3',
#    'dep/dep=3/gov=1',
#    'nummod/dep=4/gov=5',
#    'dep/dep=5/gov=3',
#    'compound/dep=6/gov=7',
#    'nummod/dep=7/gov=9',
#    'compound/dep=8/gov=9',
#    'dep/dep=9/gov=3',
#    'dep/dep=10/gov=14',
#    'nummod/dep=11/gov=10',
#    'nummod/dep=12/gov=14',
#    'nummod/dep=13/gov=14',
#    'dep/dep=14/gov=22',
#    'nummod/dep=15/gov=16',
#    'dep/dep=16/gov=14',
#    'compound/dep=17/gov=18',
#    'nummod/dep=18/gov=20',
#    'compound/dep=19/gov=20',
#    'dep/dep=20/gov=16',
#    'nummod/dep=21/gov=22'],
#   'words': ['الطائرة',
#    'السعودية',
#    'التى',
#    'خطفت',
#    'السبت',
#    'فى',
#    'الاجواء',
#    'المصرية',
#    'عادوا',
#    'الى',
#    'الرياض',
#    'مساء',
#    'امس',
#    'الاحد',
#    'من',
#    'بغداد',
#    'ثم',
#    'غادروا',
#    'فجر',
#    'اليوم',
#    'الاثنين',
#    'الى',
#    'لندن'],
#   'pos_tags': ['CD',
#    'CD',
#    'CD',
#    'CD',
#    'CD',
#    'NN',
#    'CD',
#    'CD',
#    'CD',
#    'CD',
#    'NN',
#    'CD',
#    'CD',
#    'CD',
#    'NN',
#    'CD',
#    'NN',
#    'CD',
#    'CD',
#    'CD',
#    'CD',
#    'CD',
#    'CD']},
#  'اليوم الثلاثاء ان وزير الداخلية اليمني حسين عرب اجل بناء على\nطلب صنعاء الزيارة التي كان من المقرر ان يقوم بها اليوم الى السعودية': {'events': [<__main__.Event at 0x1a1ebbce48>],
#   'penn_treebank': '(ROOT  (FRAG    (X      (X        (X          (X (SYM اليوم))          (NP            (NP (CD الثلاثاء) (CD ان))            (NP              (NP                (QP (CD وزير) (CD الداخلية))                (NN اليمني))              (NP                (QP (CD حسين) (CD عرب))                (QP (CD اجل) (CD بناء))))))        (NP          (NP (CD على) (CD طلب))          (NP            (NP              (QP (CD صنعاء) (CD الزيارة)))            (NP (CD التي) (CD كان) (NN من)))))      (NP        (NP (CD المقرر) (NN ان))        (NP          (NP            (QP (CD يقوم) (CD بها)))          (NP (CD اليوم)))))    (NP (CD الى) (CD السعودية))))',
#   'triples': ['ROOT/dep=23/gov=-1',
#    'dep/dep=0/gov=2',
#    'nummod/dep=1/gov=2',
#    'dep/dep=2/gov=11',
#    'compound/dep=3/gov=4',
#    'nummod/dep=4/gov=5',
#    'dep/dep=5/gov=2',
#    'compound/dep=6/gov=7',
#    'nummod/dep=7/gov=9',
#    'compound/dep=8/gov=9',
#    'dep/dep=9/gov=5',
#    'nummod/dep=10/gov=11',
#    'dep/dep=11/gov=18',
#    'compound/dep=12/gov=13',
#    'dep/dep=13/gov=11',
#    'nummod/dep=14/gov=16',
#    'nummod/dep=15/gov=16',
#    'dep/dep=16/gov=13',
#    'nummod/dep=17/gov=18',
#    'dep/dep=18/gov=23',
#    'compound/dep=19/gov=20',
#    'dep/dep=20/gov=18',
#    'dep/dep=21/gov=20',
#    'nummod/dep=22/gov=23'],
#   'words': ['اليوم',
#    'الثلاثاء',
#    'ان',
#    'وزير',
#    'الداخلية',
#    'اليمني',
#    'حسين',
#    'عرب',
#    'اجل',
#    'بناء',
#    'على',
#    'طلب',
#    'صنعاء',
#    'الزيارة',
#    'التي',
#    'كان',
#    'من',
#    'المقرر',
#    'ان',
#    'يقوم',
#    'بها',
#    'اليوم',
#    'الى',
#    'السعودية'],
#   'pos_tags': ['SYM',
#    'CD',
#    'CD',
#    'CD',
#    'CD',
#    'NN',
#    'CD',
#    'CD',
#    'CD',
#    'CD',
#    'CD',
#    'CD',
#    'CD',
#    'CD',
#    'CD',
#    'CD',
#    'NN',
#    'CD',
#    'NN',
#    'CD',
#    'CD',
#    'CD',
#    'CD',
#    'CD']},
#  'زيارته الى الرياض\nبناء على طلب المسؤولين اليمنيين': {'events': [<__main__.Event at 0x1a1d0c0438>],
#   'penn_treebank': '(ROOT  (NP    (NP (NN زيارته) (CD الى))    (NP      (NP (CD الرياض) (CD بناء))      (NP        (QP (CD على) (CD طلب))        (QP (CD المسؤولين) (CD اليمنيين))))))',
#   'triples': ['ROOT/dep=0/gov=-1',
#    'nummod/dep=1/gov=0',
#    'nummod/dep=2/gov=3',
#    'dep/dep=3/gov=0',
#    'compound/dep=4/gov=5',
#    'nummod/dep=5/gov=7',
#    'compound/dep=6/gov=7',
#    'dep/dep=7/gov=3'],
#   'words': ['زيارته',
#    'الى',
#    'الرياض',
#    'بناء',
#    'على',
#    'طلب',
#    'المسؤولين',
#    'اليمنيين'],
#   'pos_tags': ['NN', 'CD', 'CD', 'CD', 'CD', 'CD', 'CD', 'CD']},
#  'السعودية اليمنية كانت ستتناول اختيار الشركة التي\nسيتم تكليفها وضع العلامات" على طول الحدود البرية بين البلدين': {'events': [<__main__.Event at 0x1a1ec15b38>],
#   'penn_treebank': "(ROOT  (FRAG    (X      (NP        (NP (CD السعودية) (CD اليمنية))        (NP          (NP            (QP (CD كانت) (CD ستتناول))            (NN اختيار))          (NP            (QP (CD الشركة) (CD التي))            (QP (CD سيتم) (CD تكليفها)))))      (NP (CD وضع))      (NP        (NP (NN العلامات) ('' ''))        (NP          (NP            (QP (CD على) (CD طول)))          (NP (CD الحدود) (NN البرية)))))    (NP (CD بين) (CD البلدين))))",
#   'triples': ['ROOT/dep=17/gov=-1',
#    'nummod/dep=0/gov=1',
#    'dep/dep=1/gov=10',
#    'compound/dep=2/gov=3',
#    'nummod/dep=3/gov=4',
#    'dep/dep=4/gov=1',
#    'compound/dep=5/gov=6',
#    'nummod/dep=6/gov=8',
#    'compound/dep=7/gov=8',
#    'dep/dep=8/gov=4',
#    'dep/dep=9/gov=10',
#    'dep/dep=10/gov=17',
#    'punct/dep=11/gov=10',
#    'compound/dep=12/gov=13',
#    'dep/dep=13/gov=10',
#    'nummod/dep=14/gov=15',
#    'dep/dep=15/gov=13',
#    'nummod/dep=16/gov=17'],
#   'words': ['السعودية',
#    'اليمنية',
#    'كانت',
#    'ستتناول',
#    'اختيار',
#    'الشركة',
#    'التي',
#    'سيتم',
#    'تكليفها',
#    'وضع',
#    'العلامات',
#    "''",
#    'على',
#    'طول',
#    'الحدود',
#    'البرية',
#    'بين',
#    'البلدين'],
#   'pos_tags': ['CD',
#    'CD',
#    'CD',
#    'CD',
#    'NN',
#    'CD',
#    'CD',
#    'CD',
#    'CD',
#    'CD',
#    'NN',
#    "''",
#    'CD',
#    'CD',
#    'CD',
#    'NN',
#    'CD',
#    'CD']},
#  'زيارته': {'events': [<__main__.Event at 0x1a1ec7cc88>],
#   'penn_treebank': '(ROOT  (NP (NN زيارته)))',
#   'triples': ['ROOT/dep=0/gov=-1'],
#   'words': ['زيارته'],
#   'pos_tags': ['NN']},
#  'لوزيري\nالداخلية فى البلدين، وخصوصا "البت فى اختيار الشركة التى سوف تقوم بوضع\nالعلامات الحدودية': {'events': [<__main__.Event at 0x1a1ec15630>],
#   'penn_treebank': '(ROOT  (NP    (NP      (NP (NN لوزيري))      (SBAR        (S          (VP            (NP              (NP                (NP                  (QP (CD الداخلية) (CD فى)))                (NP (CD البلدين)))              (X (SYM ،)))))))    (NP      (NP        (NP (CD وخصوصا))        (`` ``)        (NP (FW البت) (FW فى) (FW اختيار) (FW الشركة) (FW التى) (FW سوف) (FW تقوم) (FW بوضع)))      (NP (CD العلامات) (CD الحدودية)))))',
#   'triples': ['ROOT/dep=0/gov=-1',
#    'compound/dep=1/gov=2',
#    'acl:relcl/dep=2/gov=0',
#    'dep/dep=3/gov=2',
#    'dep/dep=4/gov=2',
#    'dep/dep=5/gov=0',
#    'punct/dep=6/gov=5',
#    'compound/dep=7/gov=14',
#    'compound/dep=8/gov=14',
#    'compound/dep=9/gov=14',
#    'compound/dep=10/gov=14',
#    'compound/dep=11/gov=14',
#    'compound/dep=12/gov=14',
#    'compound/dep=13/gov=14',
#    'dep/dep=14/gov=5',
#    'nummod/dep=15/gov=16',
#    'dep/dep=16/gov=5'],
#   'words': ['لوزيري',
#    'الداخلية',
#    'فى',
#    'البلدين',
#    '،',
#    'وخصوصا',
#    '``',
#    'البت',
#    'فى',
#    'اختيار',
#    'الشركة',
#    'التى',
#    'سوف',
#    'تقوم',
#    'بوضع',
#    'العلامات',
#    'الحدودية'],
#   'pos_tags': ['NN',
#    'CD',
#    'CD',
#    'CD',
#    'SYM',
#    'CD',
#    '``',
#    'FW',
#    'FW',
#    'FW',
#    'FW',
#    'FW',
#    'FW',
#    'FW',
#    'FW',
#    'CD',
#    'CD']},
#  'المتهم': {'events': [<__main__.Event at 0x1a1dfdd588>],
#   'penn_treebank': '(ROOT  (NP (NN المتهم)))',
#   'triples': ['ROOT/dep=0/gov=-1'],
#   'words': ['المتهم'],
#   'pos_tags': ['NN']},
#  'الرئيس جوزف استرادا المتهم بقبول\nعمولات كبيرة من نقابات الالعاب': {'events': [<__main__.Event at 0x1a1dfdde10>],
#   'penn_treebank': '(ROOT  (NP    (NP      (NP (NN الرئيس))      (NP        (QP (SYM جوزف) (CD استرادا) (CD المتهم))        (QP (CD بقبول) (CD عمولات))))    (NP      (NP (CD كبيرة) (NN من))      (NP        (QP (CD نقابات) (CD الالعاب))))))',
#   'triples': ['ROOT/dep=0/gov=-1',
#    'dep/dep=1/gov=3',
#    'compound/dep=2/gov=3',
#    'nummod/dep=3/gov=5',
#    'compound/dep=4/gov=5',
#    'dep/dep=5/gov=0',
#    'nummod/dep=6/gov=7',
#    'dep/dep=7/gov=0',
#    'compound/dep=8/gov=9',
#    'dep/dep=9/gov=7'],
#   'words': ['الرئيس',
#    'جوزف',
#    'استرادا',
#    'المتهم',
#    'بقبول',
#    'عمولات',
#    'كبيرة',
#    'من',
#    'نقابات',
#    'الالعاب'],
#   'pos_tags': ['NN', 'SYM', 'CD', 'CD', 'CD', 'CD', 'CD', 'NN', 'CD', 'CD']},
#  'استقالة استرادا': {'events': [<__main__.Event at 0x1a1dfdd160>],
#   'penn_treebank': '(ROOT  (FRAG    (NP (CD استقالة) (CD استرادا))))',
#   'triples': ['ROOT/dep=1/gov=-1', 'nummod/dep=0/gov=1'],
#   'words': ['استقالة', 'استرادا'],
#   'pos_tags': ['CD', 'CD']},
#  'تتولى': {'events': [<__main__.Event at 0x1a1dfddef0>],
#   'penn_treebank': '(ROOT  (X (SYM تتولى)))',
#   'triples': ['ROOT/dep=0/gov=-1'],
#   'words': ['تتولى'],
#   'pos_tags': ['SYM']},
#  'عزل الرئيس جوزف استرادا المتهم بقبول\nعمولات كبيرة من نقابات الالعاب': {'events': [<__main__.Event at 0x1a1f307ac8>],
#   'penn_treebank': '(ROOT  (FRAG    (X      (NP        (NP (CD عزل) (CD الرئيس))        (NP (CD جوزف) (CD استرادا)))      (NP (NN المتهم) (CD بقبول))      (NP        (NP (CD عمولات))        (NP (CD كبيرة) (NN من))))    (NP (CD نقابات) (CD الالعاب))))',
#   'triples': ['ROOT/dep=10/gov=-1',
#    'nummod/dep=0/gov=1',
#    'dep/dep=1/gov=6',
#    'nummod/dep=2/gov=3',
#    'dep/dep=3/gov=1',
#    'dep/dep=4/gov=6',
#    'nummod/dep=5/gov=4',
#    'dep/dep=6/gov=10',
#    'nummod/dep=7/gov=8',
#    'dep/dep=8/gov=6',
#    'nummod/dep=9/gov=10'],
#   'words': ['عزل',
#    'الرئيس',
#    'جوزف',
#    'استرادا',
#    'المتهم',
#    'بقبول',
#    'عمولات',
#    'كبيرة',
#    'من',
#    'نقابات',
#    'الالعاب'],
#   'pos_tags': ['CD',
#    'CD',
#    'CD',
#    'CD',
#    'NN',
#    'CD',
#    'CD',
#    'CD',
#    'NN',
#    'CD',
#    'CD']},
#  'العزل': {'events': [<__main__.Event at 0x1a1f307160>],
#   'penn_treebank': '(ROOT  (X (SYM العزل)))',
#   'triples': ['ROOT/dep=0/gov=-1'],
#   'words': ['العزل'],
#   'pos_tags': ['SYM']},
#  'استرادا قبض مبلغ 400 مليون بيزوس (ثمانية ملايين دولار': {'events': [<__main__.Event at 0x1a1dfdd2b0>],
#   'penn_treebank': '(ROOT  (NP    (NP      (NP        (QP (CD استرادا) (CD قبض)))      (NP (NN مبلغ) (CD 400)))    (NP      (NP (CD مليون) (NN بيزوس))      (-LRB- -LRB-)      (NP        (NP          (QP (CD ثمانية) (CD ملايين)))        (NP (CD دولار))))))',
#   'triples': ['ROOT/dep=1/gov=-1',
#    'compound/dep=0/gov=1',
#    'dep/dep=2/gov=1',
#    'nummod/dep=3/gov=2',
#    'nummod/dep=4/gov=5',
#    'dep/dep=5/gov=1',
#    'punct/dep=6/gov=5',
#    'compound/dep=7/gov=8',
#    'dep/dep=8/gov=5',
#    'dep/dep=9/gov=8'],
#   'words': ['استرادا',
#    'قبض',
#    'مبلغ',
#    '400',
#    'مليون',
#    'بيزوس',
#    '-LRB-',
#    'ثمانية',
#    'ملايين',
#    'دولار'],
#   'pos_tags': ['CD', 'CD', 'NN', 'CD', 'CD', 'NN', '-LRB-', 'CD', 'CD', 'CD']},
#  'باستقالة استرادا': {'events': [<__main__.Event at 0x1a1dfdd748>],
#   'penn_treebank': '(ROOT  (FRAG    (NP (CD باستقالة) (CD استرادا))))',
#   'triples': ['ROOT/dep=1/gov=-1', 'nummod/dep=0/gov=1'],
#   'words': ['باستقالة', 'استرادا'],
#   'pos_tags': ['CD', 'CD']},
#  ...}

# %%
#sent = "There was the free press in Qatar, al Jeezera but its' offices in\nKabul and Baghdad were bombed by Americans"
#sent = "Compare & Contrast GWB's Vision, Leadership, Excellent Management\nTalents, Endurance, Faith And Intelligence With LBJ's Lack Of Same In\nThe Vietnam War"
sent = "Compare &amp; Contrast GWB's Vision, Leadership, Excellent Management
Talents, Endurance, Faith And Intelligence With LBJ's Lack Of Same In
The Vietnam War"
start = 589 - 437
end = 591 - 437 
print(start)
print(sent[152:])
print(len(sent))
print(end)
# Out:
# I don't mean to suggest that I agree with anything David Frum says,
# but these Arafat-had-AIDS allegations remind me of what happened with
# the late Israeli singer Ofra Haza, where there was a lot of
# speculation, a mysterious death from a 'blood disease,' and then it
# came out eventually that she'd died of AIDS
# 152
# li singer Ofra Haza, where there was a lot of
# speculation, a mysterious death from a 'blood disease,' and then it
# came out eventually that she'd died of AIDS
# 309
# 154

# %%
len(events_list_lang["English"])
# Out:
# 3177

# %%
len(events_list_lang["Chinese"])
# Out:
# 1931

# %%
len(events_list_lang["Arabic"])
# Out:
# 1650

# %% [markdown]
# ## Stanford Parser:

# %%
sent = "The skeleton of a second baby has been found at a rural Wisconsin home where a 22-year-old woman's dead infant was discovered in a blue container June 8, officials sais Monday."
penn_treebank, triples, words, pos_tags, offset_start_dic, offset_end_dic, words_dict \
= find_dep_words_pos_offsets(sent)
print(triples)
# Out:
# ['ROOT/dep=9/gov=0', 'det/dep=1/gov=2', 'nsubj:pass/dep=2/gov=9', 'case/dep=3/gov=6', 'det/dep=4/gov=6', 'amod/dep=5/gov=6', 'nmod:of/dep=6/gov=2', 'aux/dep=7/gov=9', 'aux:pass/dep=8/gov=9', 'case/dep=10/gov=14', 'det/dep=11/gov=14', 'amod/dep=12/gov=14', 'compound/dep=13/gov=14', 'obl:at/dep=14/gov=9', 'advmod/dep=15/gov=23', 'det/dep=16/gov=18', 'amod/dep=17/gov=18', 'nmod:poss/dep=18/gov=21', 'case/dep=19/gov=18', 'amod/dep=20/gov=21', 'nsubj:pass/dep=21/gov=23', 'aux:pass/dep=22/gov=23', 'acl:relcl/dep=23/gov=14', 'case/dep=24/gov=27', 'det/dep=25/gov=27', 'amod/dep=26/gov=27', 'obl:in/dep=27/gov=23', 'obl:tmod/dep=28/gov=27', 'nummod/dep=29/gov=28', 'punct/dep=30/gov=27', 'appos/dep=31/gov=27', 'dep/dep=32/gov=31', 'obl:tmod/dep=33/gov=23', 'punct/dep=34/gov=9']

# %%
penn_treebank, triples, words, pos_tags, offset_start_dic, offset_end_dic, words_dict \
= find_dep_words_pos_offsets(sent)

print("words: ", words)
print("offset_start_dic: ", offset_start_dic)
print("offset_end_dic: ", offset_end_dic)
# Out:
# words:  ['Please', 'take', 'some', 'time', 'next', 'week', 'to', 'welcome', 'a', 'new', 'staff', 'member', 'for', 'Landmark', 'Education', 'in', 'Houston']
# offset_start_dic:  {0: 0, 7: 1, 12: 2, 17: 3, 22: 4, 27: 5, 32: 6, 35: 7, 43: 8, 45: 9, 49: 10, 55: 11, 62: 12, 66: 13, 75: 14, 85: 15, 88: 16}
# offset_end_dic:  {6: 1, 11: 2, 16: 3, 21: 4, 26: 5, 31: 6, 34: 7, 42: 8, 44: 9, 48: 10, 54: 11, 61: 12, 65: 13, 74: 14, 84: 15, 87: 16, 95: 17}

# %%
for sent in list(events_list_lang["English"])[0:2]:
    penn_treebank, triples, words, pos_tags, offset_start_dic, offset_end_dic, words_dict = find_dep_words_pos_offsets(sent)
    print("words: ", words)
    print("offset_start_dic: ", offset_start_dic)
    print("offset_end_dic: ", offset_end_dic)
    for event in events_list_lang["English"][sent]:
        for entity in event.entities:
            print("start:", entity.start, " end:", entity.end)
    print("------------------------------------------------\n\n")
# Out:
#   File "<ipython-input-411-4b2401425358>", line 1
#     for #sent in list(events_list_lang["English"])[0:2]:
#                                                         ^
# SyntaxError: invalid syntax

# %% [markdown]
# ## Create json object:

# %%
import json
from tqdm import tqdm

data_json_dic = {}
for lang in ['English', 'Chinese', 'Arabic']:
    sent_json = []
    data_json = []
    for sent in tqdm(events_list_lang[lang]):
        sent_json.append(sent)
        data_sub = {}
        data_sub["golden-event-mentions"] = []
        entities_unique = {}
        for event in events_list_lang[lang][sent]["events"]:
            event_info = {}
            #(self, event_id, mention_id, type_, subtype, modality, polarity, genericity, 
            # tense, extent, scope, trig_text, trig_start, trig_end, arguments):

            event_info["trigger"] = {"start": event.trig_start, "end": event.trig_end, "text": event.trig_text}
            event_info["arguments"] = []
            for arg in event.arguments:
                arg_info = {"start": arg.start, "role": arg.role, "end": arg.end, "text": arg.text}
                event_info["arguments"].append(arg_info)

            event_info["id"] = event.event_id
            event_info["event_type"] = event.type_
            data_sub["golden-event-mentions"].append(event_info) 

            # Loading entities for that event and adding it to the list of entities
            for entity in event.entities:
                entities_unique.update({entity.id_:entity})

        data_sub["golden-entity-mentions"] = []
        for entity_id in entities_unique.keys():
            entity_info = {"phrase-type": entities_unique[entity_id].phrase_type, "end": entities_unique[entity_id].end, "text": entities_unique[entity_id].text, "entity-type": entities_unique[entity_id].entity_type, "start": entities_unique[entity_id].start, "id": entity_id}
            data_sub["golden-entity-mentions"].append(entity_info)

        #triples, words, pos_tags = find_stanford_colcc(sent)
        data_json.append({"penn_treebank": events_list_lang[lang][sent]["penn_treebank"], "stanford-colcc": events_list_lang[lang][sent]["triples"], "words": events_list_lang[lang][sent]["words"], "pos-tags" :events_list_lang[lang][sent]["pos_tags"], "golden-entity-mentions": data_sub["golden-entity-mentions"], "golden-event-mentions": data_sub["golden-event-mentions"]})
    data_json_dic.update({lang: data_json})
# Out:
#   0%|          | 0/3640 [00:00<?, ?it/s]
#
#
# 100%|██████████| 3640/3640 [00:00<00:00, 54074.81it/s]
#
#
#   0%|          | 0/2436 [00:00<?, ?it/s]
#
#
# 100%|██████████| 2436/2436 [00:00<00:00, 53262.39it/s]
#
#
#   0%|          | 0/2196 [00:00<?, ?it/s]
#
#
# 100%|██████████| 2196/2196 [00:00<00:00, 53241.30it/s]

# %% [markdown]
# ## Train/Test/Dev:

# %%
import random
random.shuffle(data_json)

# %%
save_path = "/Users/d22admin/USCGDrive/Spring19/ISI/EventExtraction/3Datasets/EventsExtraction/ACE/ace-05-splits/"
lang = "Arabic"

# %%
random.shuffle(data_json_dic[lang])
with open(save_path+ lang + '/train.json', 'w') as outfile:
    json.dump(data_json_dic[lang][:2000], outfile)

# %%
with open(save_path + lang+ '/dev.json', 'w') as outfile:
    json.dump(data_json_dic[lang][2000:2250], outfile)

# %%
with open(save_path + lang + '/test.json', 'w') as outfile:
    json.dump(data_json_dic[lang][2250:], outfile)
